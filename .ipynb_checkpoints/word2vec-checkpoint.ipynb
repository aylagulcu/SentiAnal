# %% [markdown]
# # Pre-process all the data

# %%
# Corpus reader:
import numpy as np
import random

import os
root = './Confs_newline/Conf1/'
from nltk.corpus.reader import CategorizedPlaintextCorpusReader
reader = CategorizedPlaintextCorpusReader(root, r'.*\.txt', cat_pattern=r'(\w+)/*', encoding='utf-8')

# %%
print(reader.categories())
print(reader.fileids())
# Out:
# ['kiz', 'kork', 'mutlu']
# ['kiz.txt', 'kork.txt', 'mutlu.txt']

# %%
### First, tokenize Punctuation: 
# create a token dictionary:
punc_dict= {'.':'||PERIOD||', ',': '||COMMA||', '"': '||QUOTATION_MARK||', ';': '||SEMICOLON||',
                '!': '||EXCLAMATION_MARK||', '?': '||QUESTION_MARK||', '(': '||LEFT_PAREN||',
                ')': '||RIGHT_PAREN||', '?': '||QUESTION_MARK||', 
                '\n': '||NEW_LINE||', '-': '||DASH||'}

# %%
def sent_tokenize_whole_tweets(text): # raw text --> whole tweets file content
    for key, token in punc_dict.items():
        text = text.replace(key, ' {} '.format(token))

    sentences= []
    for line in text.split('||NEW_LINE||'):
        line= line.strip()
        sentences.append(line)
    return sentences

# %%
all_text=[]
labels= []

# %%
for label,file_name in zip(reader.categories(), reader.fileids()):
    sentences= sent_tokenize_whole_tweets(reader.raw(file_name)) # --> this should return a list of contents
    labels.extend([label for i in sentences])
    all_text.extend([i.lower() for i in sentences])

# Now, we have all tweets in all_text list!

# %% [markdown]
# ## Transforming Text into Numbers

# %%
word_counts={}
for i in range(len(all_text)):
    for word in all_text[i].split(" "):
        word_counts[word] = word_counts.get(word,0) +1

vocab = set(word_counts.keys())
vocab_size = len(vocab)

print("Number of unique words: {} ".format(vocab_size))
print("Number of tweets: {}".format(len(all_text)))
assert len(all_text)== len(labels), "Each tweet should have a label."

sorted_word_counts= sorted(word_counts, key= word_counts.get, reverse= True)

int_to_vocab= {ii: word for ii,word in enumerate(sorted_word_counts)}
vocab_to_int= {word: ii for ii, word in int_to_vocab.items()}
# Out:
# Number of unique words: 7426
# Number of tweets: 2170

# %%
all_text[2]
# Out:
# 'hayır çok severim diziyi yani aşırı kızdım'

# %%
int_to_vocab[0]
# Out:
# ''

# %% [markdown]
# # Reducing Noise in the Input Data

# %% [markdown]
# ## Subsampling
#
# Words that show up often such as "the", "of", and "for" don't provide much context to the nearby words. If we discard some of them, we can remove some of the noise from our data and in return get faster training and better representations. This process is called subsampling by Mikolov. For each word $w_i$ in the training set, we'll discard it with probability given by
#
# $$ P(w_i) = 1 - \sqrt{\frac{t}{f(w_i)}} $$
#
# where $t$ is a threshold parameter and $f(w_i)$ is the frequency of word $w_i$ in the total dataset.
#
# $$ P(0) = 1 - \sqrt{\frac{1*10^{-5}}{1*10^6/16*10^6}} = 0.98735 $$

# %%
int_words = [vocab_to_int[word] for word in vocab]
print(int_words[:5])
# Out:
# [0, 892, 2028, 1620, 1609]

# %%
threshold = 1e-4

word_counts_intwords = {vocab_to_int[word]:count for word,count in word_counts.items()}
total_count = vocab_size
freqs = {word: count/total_count for word, count in word_counts_intwords.items()}
p_drop = {word: 1 - np.sqrt(threshold/freqs[word]) for word in word_counts_intwords}
# discard some frequent words, according to the subsampling equation
# create a new list of words for training

selected_words = [word for word in word_counts_intwords if random.random() < (1 - p_drop[word])]
print(selected_words[:30])
# Out:
# [6, 2140, 2141, 2142, 2144, 2145, 631, 843, 632, 633, 2147, 2148, 2149, 406, 2150, 844, 635, 2151, 2152, 2153, 1230, 637, 251, 2154, 2155, 1231, 2156, 2157, 2158, 2159]

# %%
len(selected_words)
# Out:
# 5536

# %%
all_text[0]
# Out:
# 'çok kızdım ne kadar ayıp şey'

# %%
for i in range(len(all_text)):
    line_split= all_text[i].split(" ")
    line_split_reduced= [word for word in line_split if vocab_to_int[word] in selected_words]
    all_text[i]= ' '.join(line_split_reduced)

# %% [markdown]
# # Delete empty tweets:

# %%
len(all_text)
# Out:
# 2170

# %%
all_text= [line for line in all_text if len(line)>0]
labels= [labels[i] for i in range(len(all_text)) if len(all_text[i])>0]

print("Number of tweets after reducing some noise: {}".format(len(all_text)))
assert len(all_text)== len(labels), "Each tweet should have a label."
# Out:
# Number of tweets after reducing some noise: 2059

# %% [markdown]
# # Encoding the words
# The embedding lookup requires that we pass in integers to our network. The easiest way to do this is to create dictionaries that map the words in the vocabulary to integers. Then we can convert each of our reviews into integers so they can be passed into the network.

# %%
word_counts={}
for i in range(len(all_text)):
    for word in all_text[i].split(" "):
        word_counts[word] = word_counts.get(word,0) +1

vocab = set(word_counts.keys())
vocab_size = len(vocab)
print("Number of unique words: {} ".format(vocab_size))

sorted_word_counts= sorted(word_counts, key= word_counts.get, reverse= True)

int_to_vocab= {ii: word for ii,word in enumerate(sorted_word_counts, 0)} #start from 1.
vocab_to_int= {word: ii for ii, word in int_to_vocab.items()}
# Out:
# Number of unique words: 5536

# %%
## use the dict to tokenize each review in reviews_split
## store the tokenized reviews in reviews_ints
encoded_tweets = []
for tweet in all_text:
    encoded_tweets.append([vocab_to_int[word] for word in tweet.split(" ")])

# %% [markdown]
# # Encoding the labels

# %%
def map_label(l):
    if l== 'kiz':
        return 0
    elif l== 'kork':
        return 1
    return 2

# %%
encoded_labels = np.array([map_label(label) for label in labels])

# %% [markdown]
# # Word2Vec model:

# %%
import numpy as np
def get_target(words, idx, window_size=5):
    ''' Get a list of words in a window around an index. '''
    
    R = np.random.randint(1, window_size+1)
    start = idx - R if (idx - R) > 0 else 0
    stop = idx + R
    target_words = words[start:idx] + words[idx+1:stop+1]
    
    return list(target_words)

# %%
def get_batches(words, batch_size, window_size=5):
    ''' Create a generator of word batches as a tuple (inputs, targets) '''
    
    n_batches = len(words)//batch_size
    
    # only full batches
    words = words[:n_batches*batch_size]
    
    for idx in range(0, len(words), batch_size):
        x, y = [], []
        batch = words[idx:idx+batch_size]
        for ii in range(len(batch)):
            batch_x = batch[ii]
            batch_y = get_target(batch, ii, window_size)
            y.extend(batch_y)
            x.extend([batch_x]*len(batch_y))
        yield x, y

# %%
x,y = next(get_batches(encoded_tweets, batch_size=4, window_size=5))

print('x\n', x)
print('y\n', y)
# Out:
# x
#  [[1039], [1039], [1039], [57, 1040, 1041, 1042, 1043, 1044], [57, 1040, 1041, 1042, 1043, 1044], [273, 182], [273, 182], [273, 182], [467, 0, 183, 1045, 1046, 1047], [467, 0, 183, 1045, 1046, 1047], [467, 0, 183, 1045, 1046, 1047]]
# y
#  [[57, 1040, 1041, 1042, 1043, 1044], [273, 182], [467, 0, 183, 1045, 1046, 1047], [1039], [273, 182], [1039], [57, 1040, 1041, 1042, 1043, 1044], [467, 0, 183, 1045, 1046, 1047], [1039], [57, 1040, 1041, 1042, 1043, 1044], [273, 182]]

# %%
extended_tweets= []
for line in encoded_tweets:
    extended_tweets.extend(line)

# %%
extended_tweets
# Out:
# [1039,
#  57,
#  1040,
#  1041,
#  1042,
#  1043,
#  1044,
#  273,
#  182,
#  467,
#  0,
#  183,
#  1045,
#  1046,
#  1047,
#  0,
#  468,
#  469,
#  468,
#  1048,
#  1049,
#  1050,
#  1051,
#  5,
#  0,
#  0,
#  1052,
#  1053,
#  9,
#  1054,
#  1055,
#  1056,
#  1057,
#  184,
#  1058,
#  470,
#  1059,
#  1060,
#  273,
#  30,
#  0,
#  1061,
#  471,
#  185,
#  472,
#  6,
#  6,
#  473,
#  1062,
#  1063,
#  1064,
#  1065,
#  1066,
#  0,
#  145,
#  1067,
#  474,
#  0,
#  1068,
#  1069,
#  274,
#  1070,
#  475,
#  186,
#  102,
#  476,
#  476,
#  3,
#  275,
#  0,
#  477,
#  478,
#  1071,
#  1072,
#  1073,
#  1074,
#  0,
#  1075,
#  276,
#  1076,
#  0,
#  121,
#  1077,
#  0,
#  122,
#  146,
#  1078,
#  9,
#  479,
#  1079,
#  1080,
#  20,
#  0,
#  480,
#  31,
#  31,
#  1081,
#  31,
#  1082,
#  31,
#  31,
#  480,
#  31,
#  31,
#  481,
#  0,
#  7,
#  1083,
#  1084,
#  482,
#  482,
#  1085,
#  3,
#  483,
#  0,
#  0,
#  1086,
#  1087,
#  0,
#  0,
#  1088,
#  484,
#  1089,
#  0,
#  0,
#  0,
#  1090,
#  485,
#  0,
#  147,
#  0,
#  486,
#  0,
#  0,
#  0,
#  27,
#  1091,
#  0,
#  0,
#  183,
#  37,
#  123,
#  1092,
#  1093,
#  103,
#  104,
#  1094,
#  277,
#  1095,
#  1096,
#  1097,
#  187,
#  44,
#  1098,
#  1099,
#  1100,
#  1101,
#  0,
#  1102,
#  1103,
#  0,
#  188,
#  45,
#  1104,
#  1105,
#  1106,
#  23,
#  0,
#  23,
#  487,
#  1107,
#  1,
#  1108,
#  278,
#  1109,
#  44,
#  105,
#  9,
#  79,
#  279,
#  488,
#  1110,
#  1111,
#  1112,
#  489,
#  490,
#  1113,
#  3,
#  1114,
#  3,
#  1115,
#  0,
#  1116,
#  9,
#  1117,
#  491,
#  1118,
#  9,
#  44,
#  1119,
#  491,
#  1120,
#  106,
#  1121,
#  1122,
#  280,
#  68,
#  281,
#  1123,
#  1124,
#  124,
#  1125,
#  189,
#  1126,
#  1127,
#  1128,
#  1129,
#  1130,
#  52,
#  18,
#  125,
#  125,
#  1131,
#  80,
#  1132,
#  148,
#  1133,
#  0,
#  1134,
#  1135,
#  148,
#  1136,
#  0,
#  492,
#  1137,
#  1138,
#  1139,
#  1140,
#  1141,
#  148,
#  10,
#  0,
#  1142,
#  1143,
#  1144,
#  1145,
#  282,
#  190,
#  1146,
#  1147,
#  0,
#  148,
#  0,
#  283,
#  1148,
#  81,
#  1149,
#  3,
#  284,
#  1150,
#  20,
#  285,
#  1151,
#  493,
#  494,
#  107,
#  286,
#  1152,
#  1153,
#  108,
#  1154,
#  1155,
#  1156,
#  495,
#  1157,
#  1158,
#  28,
#  0,
#  124,
#  1159,
#  109,
#  1160,
#  1161,
#  9,
#  1162,
#  1163,
#  1164,
#  25,
#  0,
#  1165,
#  496,
#  1166,
#  191,
#  497,
#  1167,
#  1168,
#  9,
#  1169,
#  1170,
#  1171,
#  32,
#  1172,
#  1173,
#  108,
#  0,
#  0,
#  0,
#  32,
#  1174,
#  192,
#  0,
#  287,
#  25,
#  32,
#  1175,
#  0,
#  193,
#  82,
#  69,
#  1176,
#  39,
#  1177,
#  82,
#  1178,
#  1179,
#  288,
#  0,
#  2,
#  0,
#  1180,
#  0,
#  289,
#  289,
#  1181,
#  1182,
#  1183,
#  46,
#  53,
#  1184,
#  1185,
#  498,
#  21,
#  2,
#  0,
#  1186,
#  1187,
#  1188,
#  0,
#  1189,
#  1190,
#  7,
#  1191,
#  40,
#  2,
#  1192,
#  499,
#  1193,
#  83,
#  0,
#  2,
#  0,
#  1194,
#  1195,
#  1196,
#  1197,
#  2,
#  500,
#  1198,
#  31,
#  1199,
#  194,
#  1200,
#  501,
#  0,
#  2,
#  0,
#  1201,
#  1202,
#  2,
#  149,
#  1203,
#  2,
#  7,
#  1204,
#  33,
#  24,
#  126,
#  1205,
#  24,
#  0,
#  502,
#  84,
#  1206,
#  12,
#  24,
#  0,
#  195,
#  1207,
#  0,
#  1208,
#  1209,
#  1210,
#  1211,
#  503,
#  1212,
#  12,
#  24,
#  24,
#  1213,
#  24,
#  0,
#  290,
#  70,
#  1214,
#  24,
#  1215,
#  1216,
#  1217,
#  291,
#  1218,
#  1219,
#  292,
#  12,
#  24,
#  293,
#  1220,
#  495,
#  1221,
#  504,
#  1222,
#  24,
#  20,
#  1223,
#  1224,
#  505,
#  1225,
#  1226,
#  1227,
#  1228,
#  0,
#  21,
#  0,
#  506,
#  506,
#  1,
#  1229,
#  1230,
#  294,
#  58,
#  1231,
#  1232,
#  507,
#  33,
#  1233,
#  508,
#  1234,
#  105,
#  1235,
#  1236,
#  1237,
#  1238,
#  295,
#  1239,
#  1240,
#  18,
#  0,
#  27,
#  1241,
#  0,
#  1242,
#  1243,
#  1244,
#  121,
#  1245,
#  1246,
#  1247,
#  1248,
#  0,
#  0,
#  0,
#  1249,
#  1250,
#  1251,
#  1252,
#  6,
#  6,
#  16,
#  0,
#  150,
#  1253,
#  296,
#  27,
#  1254,
#  0,
#  105,
#  1255,
#  1256,
#  1257,
#  68,
#  196,
#  1258,
#  0,
#  16,
#  0,
#  1259,
#  0,
#  509,
#  1260,
#  1261,
#  16,
#  510,
#  0,
#  297,
#  1262,
#  510,
#  16,
#  0,
#  147,
#  1263,
#  1264,
#  511,
#  110,
#  44,
#  22,
#  22,
#  16,
#  292,
#  1265,
#  1266,
#  30,
#  1267,
#  1268,
#  30,
#  197,
#  512,
#  298,
#  299,
#  513,
#  514,
#  1269,
#  185,
#  198,
#  1270,
#  1271,
#  300,
#  301,
#  515,
#  1272,
#  516,
#  33,
#  0,
#  517,
#  1273,
#  1274,
#  518,
#  519,
#  1275,
#  1276,
#  16,
#  41,
#  1277,
#  21,
#  520,
#  1278,
#  199,
#  188,
#  1279,
#  1280,
#  34,
#  1281,
#  16,
#  1282,
#  1283,
#  1284,
#  16,
#  1285,
#  302,
#  303,
#  1286,
#  1287,
#  1288,
#  521,
#  16,
#  1289,
#  522,
#  1290,
#  523,
#  0,
#  304,
#  16,
#  151,
#  1291,
#  305,
#  111,
#  27,
#  10,
#  1292,
#  200,
#  16,
#  6,
#  6,
#  16,
#  0,
#  0,
#  0,
#  1293,
#  1294,
#  1295,
#  1296,
#  152,
#  524,
#  16,
#  0,
#  525,
#  1297,
#  1298,
#  1299,
#  1300,
#  1301,
#  16,
#  526,
#  5,
#  527,
#  16,
#  153,
#  1302,
#  1303,
#  1304,
#  16,
#  1305,
#  1306,
#  1307,
#  1308,
#  528,
#  16,
#  0,
#  1309,
#  1310,
#  16,
#  1311,
#  1312,
#  59,
#  0,
#  529,
#  108,
#  16,
#  1313,
#  530,
#  530,
#  1314,
#  1315,
#  2,
#  0,
#  1316,
#  1317,
#  0,
#  71,
#  1318,
#  0,
#  1319,
#  1320,
#  1321,
#  154,
#  2,
#  0,
#  1322,
#  0,
#  1323,
#  1324,
#  1325,
#  0,
#  0,
#  1326,
#  0,
#  1327,
#  0,
#  306,
#  0,
#  531,
#  79,
#  307,
#  1328,
#  1329,
#  532,
#  533,
#  201,
#  1330,
#  1331,
#  1332,
#  1333,
#  534,
#  1334,
#  6,
#  6,
#  12,
#  1335,
#  1336,
#  535,
#  1337,
#  1,
#  72,
#  0,
#  83,
#  308,
#  54,
#  1338,
#  1339,
#  1340,
#  309,
#  0,
#  0,
#  0,
#  1341,
#  1342,
#  0,
#  1,
#  72,
#  199,
#  536,
#  1343,
#  0,
#  1344,
#  0,
#  0,
#  0,
#  25,
#  12,
#  0,
#  1345,
#  537,
#  1346,
#  1347,
#  538,
#  1348,
#  1349,
#  1350,
#  1351,
#  1352,
#  85,
#  1353,
#  6,
#  1354,
#  1355,
#  1356,
#  5,
#  1357,
#  80,
#  1358,
#  80,
#  153,
#  1359,
#  1360,
#  310,
#  1361,
#  311,
#  1362,
#  1363,
#  1364,
#  1365,
#  1366,
#  1367,
#  1368,
#  60,
#  1369,
#  1370,
#  539,
#  202,
#  1371,
#  1372,
#  0,
#  312,
#  86,
#  1373,
#  1374,
#  1375,
#  1376,
#  1377,
#  0,
#  1378,
#  1379,
#  1380,
#  1381,
#  313,
#  1382,
#  1383,
#  540,
#  1384,
#  1385,
#  1386,
#  314,
#  1387,
#  1388,
#  1389,
#  1390,
#  9,
#  1391,
#  1392,
#  110,
#  44,
#  1393,
#  1394,
#  0,
#  0,
#  0,
#  0,
#  0,
#  0,
#  541,
#  1395,
#  60,
#  60,
#  308,
#  127,
#  1396,
#  1397,
#  1398,
#  128,
#  1399,
#  1400,
#  1401,
#  201,
#  0,
#  1402,
#  1403,
#  10,
#  1404,
#  542,
#  543,
#  55,
#  0,
#  1405,
#  1406,
#  0,
#  1407,
#  315,
#  1408,
#  1409,
#  544,
#  1410,
#  1411,
#  104,
#  1412,
#  52,
#  1413,
#  203,
#  1414,
#  1415,
#  1416,
#  1417,
#  1418,
#  1419,
#  1420,
#  1421,
#  1422,
#  0,
#  1423,
#  545,
#  1424,
#  1425,
#  1426,
#  1427,
#  1428,
#  1429,
#  0,
#  1430,
#  546,
#  1431,
#  9,
#  547,
#  1432,
#  204,
#  1433,
#  1434,
#  1435,
#  1436,
#  9,
#  1437,
#  1438,
#  1439,
#  548,
#  1440,
#  316,
#  1441,
#  1442,
#  1443,
#  1444,
#  549,
#  550,
#  1445,
#  551,
#  552,
#  1446,
#  0,
#  0,
#  61,
#  1447,
#  0,
#  0,
#  0,
#  0,
#  1448,
#  553,
#  554,
#  0,
#  0,
#  0,
#  1449,
#  205,
#  1450,
#  1451,
#  0,
#  1452,
#  317,
#  554,
#  0,
#  0,
#  9,
#  1453,
#  1454,
#  1455,
#  1456,
#  54,
#  1457,
#  0,
#  1458,
#  1459,
#  1460,
#  1461,
#  1462,
#  1463,
#  1464,
#  102,
#  0,
#  555,
#  1465,
#  1466,
#  6,
#  6,
#  1467,
#  1468,
#  73,
#  1469,
#  1470,
#  1471,
#  1472,
#  1473,
#  1474,
#  206,
#  1475,
#  206,
#  1476,
#  556,
#  1477,
#  1478,
#  205,
#  206,
#  557,
#  206,
#  1479,
#  1480,
#  87,
#  1481,
#  1482,
#  145,
#  1483,
#  81,
#  207,
#  558,
#  559,
#  560,
#  87,
#  0,
#  286,
#  559,
#  560,
#  87,
#  0,
#  561,
#  1484,
#  562,
#  287,
#  1485,
#  1486,
#  1487,
#  112,
#  1488,
#  1489,
#  1490,
#  1491,
#  0,
#  0,
#  563,
#  564,
#  1492,
#  1493,
#  1494,
#  1495,
#  1496,
#  565,
#  1497,
#  ...]

# %% [markdown]
# # The model:
# - The input words are passed in as batches of input word tokens.
# - This will go into a hidden layer of linear units (our embedding layer).
# - Then, finally into a softmax output layer.

# %% [markdown]
# ## SkipGram model
#
# An Embedding layer takes in a number of inputs, importantly:
# * **num_embeddings** – the size of the dictionary of embeddings, or how many rows you'll want in the embedding weight matrix
# * **embedding_dim** – the size of each embedding vector; the embedding dimension

# %%
def cosine_similarity(embedding, valid_size=16, valid_window=10, device='cpu'):
    """ Returns the cosine similarity of validation words with words in the embedding matrix.
        Here, embedding should be a PyTorch embedding module.
    """
    
    # Here we're calculating the cosine similarity between some random words and 
    # our embedding vectors. With the similarities, we can look at what words are
    # close to our random words.
    
    # sim = (a . b) / |a||b|
    
    embed_vectors = embedding.weight
    
    # magnitude of embedding vectors, |b|
    magnitudes = embed_vectors.pow(2).sum(dim=1).sqrt().unsqueeze(0)
    
    # pick N words from our ranges (0,window) and (1000,1000+window). lower id implies more frequent 
    valid_examples = np.array(random.sample(range(valid_window), valid_size//2))
    valid_examples = np.append(valid_examples,
                               random.sample(range(1000,1000+valid_window), valid_size//2))
    valid_examples = torch.LongTensor(valid_examples).to(device)
    
    valid_vectors = embedding(valid_examples)
    similarities = torch.mm(valid_vectors, embed_vectors.t())/magnitudes
        
    return valid_examples, similarities

# %%
import torch
from torch import nn
import torch.optim as optim

# %%
class SkipGram(nn.Module):
    def __init__(self, n_vocab, n_embed):
        super().__init__()
        
        self.embed = nn.Embedding(n_vocab, n_embed)
        self.output = nn.Linear(n_embed, n_vocab)
        self.log_softmax = nn.LogSoftmax(dim=1)
    
    def forward(self, x):
        x = self.embed(x)
        scores = self.output(x)
        log_ps = self.log_softmax(scores)
        
        return log_ps

# %% [markdown]
# ### Training
# Because we applied a softmax function to our model output, we are using NLLLoss** as opposed to cross entropy. This is because Softmax  in combination with NLLLoss = CrossEntropy loss .

# %%
# check if GPU is available
device = 'cuda' if torch.cuda.is_available() else 'cpu'

embedding_dim=100 # you can change, if you want

model = SkipGram(len(vocab_to_int), embedding_dim).to(device)
criterion = nn.NLLLoss()
optimizer = optim.Adam(model.parameters(), lr=0.003)

print_every = 30
steps = 10
epochs = 200

# train for some number of epochs
for e in range(epochs):
    
    # get input and target batches
    for inputs, targets in get_batches(extended_tweets, 32):
        steps += 1
        inputs, targets = torch.LongTensor(inputs), torch.LongTensor(targets)
        inputs, targets = inputs.to(device), targets.to(device)
        
        log_ps = model(inputs)
        loss = criterion(log_ps, targets)
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        if steps % print_every == 0:                  
            # getting examples and similarities      
            valid_examples, valid_similarities = cosine_similarity(model.embed, device=device)
            _, closest_idxs = valid_similarities.topk(3) # topk highest similarities
            
            valid_examples, closest_idxs = valid_examples.to('cpu'), closest_idxs.to('cpu')
            for ii, valid_idx in enumerate(valid_examples):
                closest_words = [int_to_vocab[idx.item()] for idx in closest_idxs[ii]][1:]
                print(int_to_vocab[valid_idx.item()] + " | " + ', '.join(closest_words))
            print("...")
# Out:
# şu | ak, kemal
# sonra | tanıştırdı, kansız
# allaş | boksa, digor
# çıktı | gönderme, üslupsan
# hoşuma | olmamı, sevgidir
# koptu | giydiriyorum, kanişimle
# sinir | hata, muamelesi
# ||period|| | kollarım, whatsapp
# şalgam | salakça, dön
# sağal | koltuk, ardayı
# analı | bebeğim, arkadaşlarımla
# basıma | rabi'mden, kuzenimle
# kulüpte | siniz, bahsede
# büyütsün | yazılmaz, geçmek
# sağlıkla | snsmksjs, şaapma
# kapalım | pembe, i̇brahim
# ...
# çıktı | gönderme, üslupsan
# koptu | giydiriyorum, kanişimle
# sinir | hata, muamelesi
# allaş | digor, boksa
# hoşuma | olmamı, sevgidir
# sabah | sürede, siktirgit
# sonra | tanıştırdı, kansız
# en | kenarı, adet
# kulüpte | siniz, bahsede
# kapalım | pembe, i̇brahim
# şalgam | salakça, dön
# babalı | ritmi, hemcinsin
# sağal | koltuk, ardayı
# gerine | geceyi, şeyeydi
# analı | bebeğim, arkadaşlarımla
# sağlıkla | snsmksjs, şaapma
# ...
# koptu | giydiriyorum, kanişimle
# ||period|| | kafeslerden, kollarım
# sonra | tanıştırdı, kansız
# sabah | sürede, siktirgit
# sinir | hata, muamelesi
# çıktı | gönderme, üslupsan
# en | kenarı, adet
# şu | ak, kemal
# büyütsün | yazılmaz, geçmek
# kapalım | pembe, i̇brahim
# basıma | rabi'mden, kuzenimle
# babalı | ritmi, hemcinsin
# kulüpte | siniz, bahsede
# gerine | geceyi, şeyeydi
# sağal | koltuk, ardayı
# sağlıkla | snsmksjs, şaapma
# ...
# şu | ak, kemal
# en | kenarı, adet
# sabah | sürede, siktirgit
# ||period|| | kafeslerden, kollarım
# hoşuma | olmamı, sevgidir
# sonra | tanıştırdı, kansız
# çıktı | gönderme, üslupsan
# allaş | digor, boksa
# sağlıkla | snsmksjs, şaapma
# şalgam | salakça, dön
# büyütsün | yazılmaz, geçmek
# kulüpte | siniz, bahsede
# kapalım | pembe, i̇brahim
# sağal | koltuk, ardayı
# gerine | geceyi, şeyeydi
# basıma | rabi'mden, kuzenimle
# ...
# ||period|| | kafeslerden, kollarım
# sinir | hata, muamelesi
# çıktı | gönderme, üslupsan
# allaş | digor, boksa
# şu | ak, kemal
# sabah | sürede, siktirgit
# en | kenarı, adet
# koptu | giydiriyorum, kanişimle
# analı | bebeğim, arkadaşlarımla
# kulüpte | siniz, bahsede
# gerine | geceyi, şeyeydi
# basıma | rabi'mden, kuzenimle
# şalgam | salakça, dön
# kapalım | pembe, i̇brahim
# sağlıkla | snsmksjs, şaapma
# büyütsün | yazılmaz, geçmek
# ...
# sinir | hata, muamelesi
# hoşuma | olmamı, sevgidir
# sonra | tanıştırdı, kansız
# ||period|| | kafeslerden, kollarım
# şu | ak, kemal
# en | kenarı, adet
# allaş | digor, boksa
# çıktı | gönderme, kendim
# kapalım | pembe, i̇brahim
# analı | bebeğim, arkadaşlarımla
# sağal | koltuk, ardayı
# kulüpte | siniz, bahsede
# gerine | geceyi, şeyeydi
# basıma | rabi'mden, kuzenimle
# büyütsün | yazılmaz, geçmek
# şalgam | salakça, dön
# ...
# sonra | tanıştırdı, kansız
# en | kenarı, adet
# ||period|| | kafeslerden, belki
# hoşuma | olmamı, sevgidir
# sinir | hata, muamelesi
# koptu | giydiriyorum, kanişimle
# allaş | digor, boksa
# şu | ak, kemal
# şalgam | salakça, dön
# basıma | rabi'mden, kuzenimle
# gerine | geceyi, şeyeydi
# kulüpte | siniz, bahsede
# sağlıkla | snsmksjs, şaapma
# analı | bebeğim, arkadaşlarımla
# sağal | koltuk, ardayı
# kapalım | pembe, i̇brahim
# ...
# ||period|| | kafeslerden, belki
# çıktı | gönderme, kendim
# allaş | digor, boksa
# sinir | hata, muamelesi
# en | kenarı, adet
# sabah | sürede, siktirgit
# hoşuma | olmamı, sevgidir
# koptu | giydiriyorum, kanişimle
# gerine | geceyi, şeyeydi
# sağlıkla | snsmksjs, hayal
# babalı | ritmi, sarma
# analı | bebeğim, arkadaşlarımla
# basıma | kuzenimle, rabi'mden
# büyütsün | yazılmaz, geçmek
# kapalım | pembe, i̇brahim
# şalgam | salakça, dön
# ...
# hoşuma | olmamı, açıldı
# sonra | tanıştırdı, kansız
# sabah | sürede, siktirgit
# çıktı | gönderme, kendim
# en | kenarı, adet
# sinir | hata, muamelesi
# allaş | digor, boksa
# şu | ak, kemal
# babalı | ritmi, sarma
# sağlıkla | hayal, şaapma
# basıma | rabi'mden, kuzenimle
# şalgam | salakça, dön
# analı | bebeğim, arkadaşlarımla
# kapalım | pembe, i̇brahim
# gerine | geceyi, şeyeydi
# büyütsün | yazılmaz, geçmek
# ...
# çıktı | gönderme, kendim
# koptu | giydiriyorum, kanişimle
# şu | ak, kemal
# sonra | tanıştırdı, kansız
# sinir | hata, muamelesi
# hoşuma | olmamı, açıldı
# allaş | digor, boksa
# sabah | sürede, siktirgit
# basıma | rabi'mden, kuzenimle
# gerine | geceyi, şeyeydi
# babalı | ritmi, sarma
# şalgam | salakça, youtubea
# sağlıkla | hayal, şaapma
# kulüpte | bahsede, kansızlar
# büyütsün | yazılmaz, geçmek
# kapalım | pembe, i̇brahim
# ...
# koptu | kanişimle, giydiriyorum
# sabah | sürede, siktirgit
# sinir | hata, muamelesi
# ||period|| | kafeslerden, belki
# hoşuma | olmamı, açıldı
# en | kenarı, adet
# sonra | tanıştırdı, kansız
# şu | ak, kemal
# kulüpte | bahsede, kansızlar
# büyütsün | yazılmaz, geçmek
# sağal | koltuk, ardayı
# şalgam | salakça, youtubea
# sağlıkla | hayal, şaapma
# basıma | rabi'mden, kuzenimle
# gerine | geceyi, şeyeydi
# analı | bebeğim, arkadaşlarımla
# ...
# en | kenarı, adet
# sinir | hata, muamelesi
# şu | ak, kemal
# allaş | digor, boksa
# koptu | kanişimle, giydiriyorum
# hoşuma | olmamı, açıldı
# çıktı | gönderme, kendim
# sabah | sürede, bağırıyı
# şalgam | salakça, youtubea
# büyütsün | yazılmaz, geçmek
# gerine | geceyi, şeyeydi
# kulüpte | bahsede, kansızlar
# sağal | koltuk, ardayı
# babalı | ritmi, sarma
# basıma | rabi'mden, kuzenimle
# sağlıkla | hayal, şaapma
# ...
# ||period|| | kafeslerden, belki
# hoşuma | olmamı, açıldı
# allaş | digor, boksa
# çıktı | gönderme, kendim
# sinir | hata, muamelesi
# sonra | kansız, tanıştırdı
# şu | ak, kemal
# koptu | kanişimle, giydiriyorum
# büyütsün | yazılmaz, geçmek
# kulüpte | bahsede, kansızlar
# basıma | rabi'mden, kuzenimle
# sağal | koltuk, ardayı
# gerine | geceyi, şeyeydi
# babalı | ritmi, sarma
# şalgam | salakça, dön
# analı | bebeğim, arkadaşlarımla
# ...
# sonra | kansız, tolga
# çıktı | gönderme, kendim
# hoşuma | olmamı, açıldı
# en | kenarı, adet
# sabah | sürede, müziği
# şu | ak, ndoye
# allaş | digor, boksa
# sinir | hata, muamelesi
# babalı | ritmi, sarma
# gerine | geceyi, şeyeydi
# sağlıkla | hayal, şaapma
# büyütsün | yazılmaz, geçmek
# kulüpte | bahsede, kansızlar
# şalgam | salakça, dön
# analı | bebeğim, arkadaşlarımla
# sağal | koltuk, ardayı
# ...
# sinir | hata, muamelesi
# şu | ak, ndoye
# allaş | digor, boksa
# hoşuma | olmamı, açıldı
# koptu | giydiriyorum, kanişimle
# en | kenarı, adet
# sabah | sürede, müziği
# çıktı | gönderme, kendim
# gerine | geceyi, şeyeydi
# şalgam | salakça, dön
# sağlıkla | hayal, şaapma
# sağal | koltuk, ardayı
# babalı | ritmi, sarma
# kapalım | pembe, i̇brahim
# basıma | rabi'mden, kuzenimle
# büyütsün | yazılmaz, geçmek
# ...
# hoşuma | olmamı, açıldı
# sinir | hata, muamelesi
# en | kenarı, adet
# çıktı | gönderme, kendim
# sonra | kansız, tolga
# ||period|| | kafeslerden, belki
# allaş | digor, boksa
# koptu | giydiriyorum, kanişimle
# kapalım | pembe, i̇brahim
# sağal | koltuk, ardayı
# analı | bebeğim, arkadaşlarımla
# gerine | geceyi, şeyeydi
# sağlıkla | hayal, şaapma
# kulüpte | bahsede, kansızlar
# büyütsün | yazılmaz, geçmek
# babalı | ritmi, sarma
# ...
# sonra | kansız, tolga
# hoşuma | olmamı, açıldı
# sabah | sürede, bağırıyı
# ||period|| | kafeslerden, belki
# en | kenarı, adet
# çıktı | gönderme, kendim
# şu | ak, ndoye
# koptu | kanişimle, giydiriyorum
# şalgam | salakça, dön
# kulüpte | bahsede, kansızlar
# büyütsün | yazılmaz, geçmek
# analı | bebeğim, arkadaşlarımla
# babalı | ritmi, sarma
# kapalım | pembe, i̇brahim
# gerine | geceyi, şeyeydi
# sağlıkla | hayal, şaapma
# ...
# çıktı | gönderme, kendim
# sabah | sürede, vallahi
# hoşuma | olmamı, açıldı
# en | kenarı, adet
# şu | ak, ndoye
# sinir | hata, muamelesi
# allaş | digor, boksa
# sonra | kansız, tolga
# basıma | rabi'mden, kuzenimle
# gerine | geceyi, şeyeydi
# babalı | ritmi, sarma
# sağal | ardayı, taraftar
# sağlıkla | hayal, şaapma
# kulüpte | bahsede, kansızlar
# analı | bebeğim, arkadaşlarımla
# büyütsün | yazılmaz, geçmek
# ...
# hoşuma | olmamı, açıldı
# şu | ak, ndoye
# sinir | hata, muamelesi
# en | kenarı, adet
# çıktı | gönderme, kendim
# sonra | kansız, tolga
# koptu | kanişimle, duramayan
# ||period|| | kafeslerden, belki
# büyütsün | yazılmaz, geçmek
# gerine | geceyi, şeyeydi
# basıma | rabi'mden, kuzenimle
# analı | bebeğim, arkadaşlarımla
# sağal | ardayı, taraftar
# şalgam | salakça, dön
# babalı | ritmi, sarma
# kapalım | pembe, i̇brahim
# ...
# en | kenarı, adet
# allaş | digor, boksa
# şu | ak, ndoye
# sinir | hata, muamelesi
# hoşuma | olmamı, açıldı
# koptu | kanişimle, duramayan
# çıktı | gönderme, kendim
# sonra | kansız, tolga
# basıma | rabi'mden, kuzenimle
# kulüpte | kansızlar, bahsede
# babalı | ritmi, sarma
# sağlıkla | snsmksjs, hayal
# analı | bebeğim, duyarlı
# sağal | taraftar, ardayı
# kapalım | pembe, i̇brahim
# şalgam | salakça, youtubea
# ...
# koptu | kanişimle, duramayan
# sinir | hata, muamelesi
# allaş | digor, boksa
# hoşuma | olmamı, açıldı
# çıktı | gönderme, kendim
# şu | ak, ndoye
# sonra | kansız, tolga
# sabah | sürede, vallahi
# büyütsün | yazılmaz, ydi
# şalgam | youtubea, salakça
# sağlıkla | snsmksjs, hayal
# analı | bebeğim, duyarlı
# gerine | geceyi, şeyeydi
# kulüpte | kansızlar, bahsede
# basıma | rabi'mden, kuzenimle
# babalı | ritmi, sarma
# ...
# ||period|| | kafeslerden, belki
# hoşuma | olmamı, açıldı
# allaş | digor, boksa
# çıktı | gönderme, kendim
# koptu | kanişimle, duramayan
# sinir | hata, muamelesi
# sonra | kansız, tolga
# sabah | sürede, vallahi
# sağlıkla | snsmksjs, hayal
# gerine | geceyi, şeyeydi
# kulüpte | kansızlar, bahsede
# sağal | sınırlarım, koltuk
# basıma | rabi'mden, kuzenimle
# analı | bebeğim, duyarlı
# kapalım | pembe, i̇brahim
# şalgam | youtubea, salakça
# ...
# sabah | vallahi, sürede
# hoşuma | olmamı, açıldı
# sonra | kansız, tolga
# sinir | hata, ister
# çıktı | gönderme, kendim
# şu | ak, ndoye
# en | kenarı, adet
# koptu | kanişimle, duramayan
# kulüpte | kansızlar, bahsede
# babalı | ritmi, sarma
# sağlıkla | snsmksjs, hayal
# sağal | sınırlarım, koltuk
# şalgam | youtubea, salakça
# basıma | rabi'mden, kuzenimle
# gerine | geceyi, şeyeydi
# analı | bebeğim, duyarlı
# ...
# koptu | kanişimle, giydiriyorum
# ||period|| | kafeslerden, belki
# hoşuma | olmamı, açıldı
# allaş | digor, boksa
# sabah | vallahi, sürede
# sonra | kansız, tolga
# şu | ak, ndoye
# çıktı | gönderme, kendim
# analı | bebeğim, duyarlı
# basıma | rabi'mden, kuzenimle
# sağal | sınırlarım, koltuk
# babalı | ritmi, sarma
# kulüpte | kansızlar, bahsede
# sağlıkla | snsmksjs, hayal
# şalgam | salakça, youtubea
# kapalım | pembe, i̇brahim
# ...
# şu | ak, ndoye
# en | kenarı, adet
# sabah | vallahi, sürede
# sinir | hata, ister
# ||period|| | kafeslerden, belki
# allaş | digor, boksa
# koptu | kanişimle, giydiriyorum
# hoşuma | olmamı, açıldı
# büyütsün | yazılmaz, ydi
# sağal | sınırlarım, koltuk
# basıma | rabi'mden, kuzenimle
# şalgam | salakça, youtubea
# babalı | ritmi, sarma
# sağlıkla | snsmksjs, hayal
# analı | bebeğim, duyarlı
# kapalım | pembe, i̇brahim
# ...
# hoşuma | olmamı, açıldı
# sinir | hata, ister
# şu | ak, ndoye
# sonra | kansız, tolga
# ||period|| | kafeslerden, malum
# en | kenarı, bole
# çıktı | gönderme, kendim
# koptu | kanişimle, giydiriyorum
# büyütsün | yazılmaz, ydi
# sağal | sınırlarım, koltuk
# babalı | ritmi, sarma
# basıma | rabi'mden, kuzenimle
# analı | bebeğim, duyarlı
# şalgam | salakça, youtubea
# sağlıkla | snsmksjs, hayal
# gerine | geceyi, şeyeydi
# ...
# sabah | vallahi, sürede
# çıktı | gönderme, kendim
# hoşuma | olmamı, açıldı
# allaş | digor, boksa
# ||period|| | kafeslerden, malum
# en | kenarı, bole
# şu | ak, ndoye
# sinir | hata, ister
# büyütsün | yazılmaz, ydi
# analı | bebeğim, duyarlı
# sağal | koltuk, sınırlarım
# şalgam | salakça, youtubea
# basıma | rabi'mden, kuzenimle
# kapalım | pembe, i̇brahim
# gerine | geceyi, şeyeydi
# babalı | ritmi, sarma
# ...
# koptu | duramayan, kanişimle
# allaş | digor, boksa
# ||period|| | kafeslerden, öpen
# sinir | hata, ister
# hoşuma | olmamı, açıldı
# çıktı | gönderme, kendim
# şu | ak, kemal
# sonra | kansız, tolga
# kulüpte | kansızlar, bahsede
# gerine | geceyi, şeyeydi
# sağal | taraftar, koltuk
# babalı | ritmi, sarma
# basıma | rabi'mden, kuzenimle
# kapalım | pembe, i̇brahim
# büyütsün | yazılmaz, izlemeyin
# sağlıkla | snsmksjs, hayal
# ...
# sonra | kansız, tolga
# allaş | digor, boksa
# çıktı | gönderme, kendim
# şu | ak, kemal
# hoşuma | olmamı, açıldı
# sinir | hata, ister
# koptu | kanişimle, seveceksin
# ||period|| | kafeslerden, öpen
# kapalım | pembe, i̇brahim
# sağal | taraftar, koltuk
# analı | bebeğim, duyarlı
# babalı | ritmi, sarma
# basıma | rabi'mden, kuzenimle
# kulüpte | kansızlar, bahsede
# şalgam | salakça, youtubea
# gerine | geceyi, şeyeydi
# ...
# sinir | hata, ister
# çıktı | gönderme, kendim
# sonra | kansız, tolga
# şu | ak, kemal
# koptu | kanişimle, seveceksin
# ||period|| | kafeslerden, belki
# en | kenarı, adet
# allaş | digor, boksa
# kulüpte | kansızlar, bahsede
# gerine | geceyi, şeyeydi
# sağal | taraftar, kuzen
# sağlıkla | hayal, snsmksjs
# kapalım | pembe, i̇brahim
# basıma | rabi'mden, çekilmiş
# şalgam | salakça, youtubea
# büyütsün | yazılmaz, ydi
# ...
# çıktı | gönderme, kendim
# allaş | digor, boksa
# sonra | kansız, tolga
# ||period|| | kafeslerden, öpen
# en | kenarı, adet
# şu | ak, kemal
# sinir | hata, ister
# hoşuma | olmamı, açıldı
# babalı | sarma, ritmi
# analı | bebeğim, sağlıkla
# kulüpte | kansızlar, bahsede
# sağal | kuzen, taraftar
# şalgam | salakça, youtubea
# kapalım | pembe, i̇brahim
# basıma | rabi'mden, çekilmiş
# sağlıkla | snsmksjs, hayal
# ...
# çıktı | gönderme, kendim
# şu | ak, kemal
# ||period|| | kafeslerden, öpen
# hoşuma | olmamı, açıldı
# sabah | vallahi, sürede
# en | kenarı, adet
# sonra | kansız, tolga
# allaş | digor, boksa
# sağlıkla | snsmksjs, hayal
# analı | bebeğim, sağlıkla
# kulüpte | kansızlar, bahsede
# şalgam | salakça, youtubea
# sağal | kuzen, taraftar
# büyütsün | yazılmaz, ydi
# kapalım | pembe, i̇brahim
# gerine | geceyi, şeyeydi
# ...
# en | kenarı, adet
# sonra | kansız, tolga
# allaş | digor, boksa
# koptu | seveceksin, duramayan
# sinir | hata, ister
# hoşuma | olmamı, açıldı
# çıktı | gönderme, kendim
# sabah | vallahi, sürede
# basıma | rabi'mden, çekilmiş
# sağlıkla | snsmksjs, hayal
# büyütsün | yazılmaz, ydi
# babalı | sarma, ritmi
# gerine | geceyi, şeyeydi
# sağal | kuzen, taraftar
# kapalım | pembe, i̇brahim
# şalgam | salakça, youtubea
# ...
# sonra | kansız, tolga
# allaş | digor, boksa
# sinir | ister, hata
# koptu | seveceksin, giydiriyorum
# çıktı | gönderme, kendim
# en | kenarı, bole
# sabah | vallahi, sürede
# hoşuma | olmamı, açıldı
# büyütsün | yazılmaz, ydi
# sağal | kuzen, taraftar
# basıma | rabi'mden, çekilmiş
# gerine | geceyi, şeyeydi
# şalgam | salakça, youtubea
# sağlıkla | snsmksjs, hayal
# analı | bebeğim, sağlıkla
# babalı | sarma, ritmi
# ...
# şu | ak, ndoye
# allaş | digor, boksa
# sinir | ister, hata
# hoşuma | olmamı, açıldı
# en | kenarı, bole
# sabah | vallahi, sürede
# ||period|| | kafeslerden, malum
# koptu | giydiriyorum, seveceksin
# sağal | kuzen, taraftar
# şalgam | salakça, youtubea
# kapalım | pembe, i̇brahim
# gerine | geceyi, şeyeydi
# büyütsün | yazılmaz, ydi
# analı | bebeğim, sağlıkla
# babalı | sarma, ritmi
# sağlıkla | snsmksjs, hayal
# ...
# sabah | vallahi, sürede
# koptu | giydiriyorum, seveceksin
# şu | ak, kemal
# çıktı | gönderme, kendim
# allaş | digor, boksa
# sinir | ister, hata
# en | kenarı, bole
# sonra | kansız, tolga
# gerine | geceyi, şeyeydi
# sağlıkla | snsmksjs, hayal
# analı | bebeğim, sağlıkla
# babalı | sarma, ritmi
# kulüpte | kansızlar, bahsede
# basıma | rabi'mden, çekilmiş
# şalgam | salakça, yarabbim
# büyütsün | yazılmaz, ydi
# ...
# sabah | vallahi, siktirgit
# şu | ak, kemal
# allaş | digor, boksa
# koptu | giydiriyorum, seveceksin
# hoşuma | olmamı, açıldı
# ||period|| | kafeslerden, malum
# çıktı | gönderme, kendim
# sonra | kansız, tolga
# sağlıkla | snsmksjs, hayal
# basıma | rabi'mden, çekilmiş
# sağal | kuzen, taraftar
# analı | bebeğim, sağlıkla
# kulüpte | kansızlar, bahsede
# şalgam | salakça, yarabbim
# babalı | sarma, ritmi
# büyütsün | yazılmaz, ydi
# ...
# koptu | seveceksin, giydiriyorum
# hoşuma | olmamı, açıldı
# sinir | ister, hata
# en | kenarı, bole
# sabah | vallahi, siktirgit
# allaş | digor, boksa
# şu | ak, kemal
# sonra | kansız, tolga
# büyütsün | yazılmaz, izlemeyin
# sağlıkla | snsmksjs, hayal
# analı | bebeğim, sağlıkla
# basıma | rabi'mden, asmış
# gerine | geceyi, şeyeydi
# kulüpte | kansızlar, bahsede
# kapalım | pembe, i̇brahim
# babalı | sarma, hemcinsin
# ...
# sabah | vallahi, siktirgit
# hoşuma | olmamı, açıldı
# sonra | kansız, tolga
# şu | ak, kemal
# ||period|| | kafeslerden, öpen
# sinir | ister, hata
# çıktı | gönderme, kendim
# en | kenarı, bole
# basıma | rabi'mden, asmış
# büyütsün | yazılmaz, izlemeyin
# şalgam | salakça, yarabbim
# kulüpte | kansızlar, bahsede
# analı | bebeğim, sağlıkla
# sağal | kuzen, taraftar
# kapalım | pembe, i̇brahim
# sağlıkla | snsmksjs, şaapma
# ...
# sinir | ister, hata
# şu | ak, kemal
# en | kenarı, bole
# hoşuma | olmamı, açıldı
# allaş | boksa, digor
# ||period|| | kafeslerden, yormaz
# sonra | kansız, tolga
# koptu | seveceksin, duramayan
# kulüpte | kansızlar, açtı
# analı | sağlıkla, bebeğim
# şalgam | salakça, yarabbim
# gerine | geceyi, şeyeydi
# kapalım | pembe, i̇brahim
# basıma | rabi'mden, çekilmiş
# sağal | kuzen, taraftar
# büyütsün | yazılmaz, izlemeyin
# ...
# en | kenarı, bole
# çıktı | gönderme, kendim
# hoşuma | olmamı, açıldı
# ||period|| | kafeslerden, yormaz
# şu | ak, kemal
# sinir | ister, hata
# allaş | digor, boksa
# sonra | kansız, tolga
# babalı | sarma, içmeyeceksin
# basıma | rabi'mden, çekilmiş
# büyütsün | yazılmaz, izlemeyin
# kapalım | pembe, i̇brahim
# gerine | geceyi, şeyeydi
# kulüpte | kansızlar, açtı
# sağlıkla | snsmksjs, hayal
# analı | sağlıkla, bebeğim
# ...
# sonra | kansız, tolga
# sabah | vallahi, siktirgit
# ||period|| | kafeslerden, yormaz
# çıktı | gönderme, kendim
# en | kenarı, bole
# koptu | seveceksin, duramayan
# allaş | boksa, digor
# şu | ak, kemal
# babalı | sarma, içmeyeceksin
# kapalım | pembe, i̇brahim
# sağlıkla | snsmksjs, hayal
# büyütsün | yazılmaz, aynadan
# basıma | rabi'mden, çekilmiş
# analı | sağlıkla, bebeğim
# gerine | geceyi, şeyeydi
# kulüpte | kansızlar, açtı
# ...
# sabah | vallahi, siktirgit
# allaş | boksa, digor
# hoşuma | olmamı, açıldı
# sinir | ister, hata
# koptu | seveceksin, duramayan
# şu | ak, kemal
# sonra | kansız, tolga
# çıktı | gönderme, kendim
# babalı | sarma, içmeyeceksin
# sağlıkla | snsmksjs, hayal
# analı | sağlıkla, bebeğim
# basıma | rabi'mden, çekilmiş
# şalgam | salakça, çikolatanızı
# sağal | kuzen, taraftar
# gerine | geceyi, şeyeydi
# kapalım | pembe, şoförü
# ...
# hoşuma | olmamı, açıldı
# sinir | ister, hata
# ||period|| | kafeslerden, malum
# şu | ak, kemal
# allaş | boksa, digor
# çıktı | gönderme, kendim
# sonra | kansız, tolga
# sabah | vallahi, siktirgit
# şalgam | salakça, çikolatanızı
# analı | sağlıkla, bebeğim
# gerine | geceyi, şeyeydi
# sağal | kuzen, taraftar
# sağlıkla | snsmksjs, hayal
# kapalım | pembe, şoförü
# babalı | sarma, içmeyeceksin
# basıma | rabi'mden, asmış
# ...
# sabah | vallahi, siktirgit
# ||period|| | kafeslerden, malum
# koptu | seveceksin, duramayan
# allaş | boksa, digor
# hoşuma | olmamı, açıldı
# şu | ak, ndoye
# sonra | kansız, tolga
# sinir | ister, hata
# babalı | sarma, içmeyeceksin
# kapalım | pembe, şoförü
# basıma | rabi'mden, asmış
# büyütsün | yazılmaz, aynadan
# sağal | kuzen, taraftar
# analı | sağlıkla, bebeğim
# kulüpte | kansızlar, açtı
# gerine | geceyi, şeyeydi
# ...
# hoşuma | olmamı, açıldı
# en | kenarı, bole
# allaş | boksa, digor
# ||period|| | kafeslerden, malum
# sinir | ister, hata
# sonra | kansız, tolga
# çıktı | gönderme, kendim
# sabah | vallahi, siktirgit
# şalgam | salakça, yarabbim
# kapalım | pembe, şoförü
# kulüpte | kansızlar, açtı
# analı | sağlıkla, bebeğim
# basıma | rabi'mden, asmış
# büyütsün | yazılmaz, aynadan
# gerine | geceyi, şeyeydi
# sağal | kuzen, taraftar
# ...
# koptu | giydiriyorum, duramayan
# ||period|| | kafeslerden, malum
# sonra | kansız, tolga
# sinir | ister, hata
# şu | ak, kemal
# allaş | boksa, digor
# sabah | vallahi, siktirgit
# hoşuma | olmamı, açıldı
# basıma | rabi'mden, asmış
# babalı | sarma, içmeyeceksin
# sağal | kuzen, taraftar
# kapalım | pembe, şoförü
# gerine | geceyi, şeyeydi
# kulüpte | kansızlar, açtı
# sağlıkla | snsmksjs, şaapma
# büyütsün | yazılmaz, aynadan
# ...
# ||period|| | kafeslerden, malum
# allaş | boksa, digor
# sinir | ister, hata
# koptu | duramayan, seveceksin
# en | kenarı, bole
# sabah | vallahi, siktirgit
# çıktı | gönderme, kendim
# hoşuma | olmamı, açıldı
# analı | sağlıkla, bebeğim
# babalı | sarma, içmeyeceksin
# sağlıkla | snsmksjs, şaapma
# büyütsün | yazılmaz, izlemeyin
# basıma | rabi'mden, asmış
# kulüpte | kansızlar, açtı
# sağal | kuzen, taraftar
# şalgam | salakça, yarabbim
# ...
# hoşuma | olmamı, açıldı
# çıktı | gönderme, kendim
# en | kenarı, bole
# sabah | vallahi, siktirgit
# şu | ak, kemal
# koptu | duramayan, seveceksin
# ||period|| | kafeslerden, malum
# sinir | ister, hata
# kulüpte | kansızlar, açtı
# sağlıkla | snsmksjs, şaapma
# analı | sağlıkla, bebeğim
# büyütsün | yazılmaz, izlemeyin
# babalı | sarma, içmeyeceksin
# gerine | geceyi, şeyeydi
# kapalım | pembe, şoförü
# şalgam | salakça, yarabbim
# ...
# hoşuma | olmamı, açıldı
# çıktı | gönderme, kendim
# allaş | boksa, digor
# sabah | vallahi, antrenmanı
# sonra | kansız, tolga
# sinir | ister, hata
# en | kenarı, bole
# koptu | duramayan, seveceksin
# analı | sağlıkla, bebeğim
# şalgam | salakça, yarabbim
# gerine | geceyi, şeyeydi
# büyütsün | yazılmaz, izlemeyin
# kapalım | pembe, şoförü
# kulüpte | kansızlar, açtı
# babalı | sarma, içmeyeceksin
# sağlıkla | snsmksjs, şaapma
# ...
# ||period|| | kafeslerden, yormaz
# en | kenarı, bole
# sonra | kansız, tolga
# sinir | ister, hata
# şu | ak, kemal
# koptu | duramayan, seveceksin
# allaş | boksa, digor
# sabah | vallahi, siktirgit
# gerine | geceyi, şeyeydi
# sağal | kuzen, taraftar
# babalı | sarma, içmeyeceksin
# kulüpte | kansızlar, açtı
# şalgam | salakça, yarabbim
# basıma | rabi'mden, asmış
# kapalım | i̇brahim, pembe
# analı | sağlıkla, bırakmam
# ...
# sinir | ister, hata
# ||period|| | kafeslerden, yormaz
# hoşuma | olmamı, açıldı
# en | kenarı, bole
# sonra | kansız, tolga
# allaş | boksa, digor
# sabah | vallahi, siktirgit
# çıktı | gönderme, kendim
# kulüpte | kansızlar, vatandaş
# sağal | kuzen, taraftar
# sağlıkla | snsmksjs, analı
# büyütsün | yazılmaz, aynadan
# şalgam | salakça, yarabbim
# analı | sağlıkla, bırakmam
# basıma | rabi'mden, çekilmiş
# kapalım | i̇brahim, pembe
# ...
# ||period|| | kafeslerden, malum
# şu | ak, kemal
# hoşuma | olmamı, açıldı
# sinir | ister, hata
# koptu | duramayan, seveceksin
# allaş | boksa, digor
# en | kenarı, bole
# çıktı | gönderme, kendim
# sağal | kuzen, taraftar
# gerine | geceyi, şeyeydi
# sağlıkla | snsmksjs, analı
# büyütsün | yazılmaz, aynadan
# kapalım | şoförü, i̇brahim
# babalı | sarma, içmeyeceksin
# basıma | rabi'mden, çekilmiş
# kulüpte | kansızlar, vatandaş
# ...
# şu | ak, ndoye
# hoşuma | olmamı, açıldı
# sinir | ister, hata
# en | kenarı, bole
# sonra | kansız, kalırsın
# allaş | boksa, digor
# koptu | duramayan, seveceksin
# çıktı | gönderme, kendim
# kulüpte | kansızlar, vatandaş
# analı | sağlıkla, bırakmam
# büyütsün | yazılmaz, aynadan
# kapalım | şoförü, i̇brahim
# sağal | kuzen, taraftar
# sağlıkla | snsmksjs, analı
# şalgam | salakça, yarabbim
# basıma | rabi'mden, asmış
# ...
# ||period|| | kafeslerden, malum
# koptu | duramayan, seveceksin
# sonra | kansız, tolga
# sabah | vallahi, antrenmanı
# şu | ak, kemal
# çıktı | gönderme, kendim
# hoşuma | olmamı, açıldı
# sinir | ister, hata
# babalı | sarma, içmeyeceksin
# sağlıkla | snsmksjs, analı
# kapalım | şoförü, i̇brahim
# şalgam | salakça, yarabbim
# sağal | kuzen, taraftar
# kulüpte | kansızlar, vatandaş
# gerine | geceyi, şeyeydi
# büyütsün | yazılmaz, aynadan
# ...
# sonra | kansız, tolga
# koptu | duramayan, seveceksin
# çıktı | gönderme, kendim
# en | kenarı, bole
# hoşuma | olmamı, açıldı
# sabah | vallahi, müziği
# şu | ak, geçice
# allaş | boksa, digor
# kapalım | şoförü, i̇brahim
# basıma | rabi'mden, asmış
# kulüpte | kansızlar, vatandaş
# sağal | kuzen, taraftar
# şalgam | salakça, yarabbim
# büyütsün | yazılmaz, aynadan
# gerine | geceyi, şeyeydi
# analı | sağlıkla, bırakmam
# ...
# ||period|| | kafeslerden, malum
# sonra | kansız, tolga
# sabah | vallahi, müziği
# sinir | ister, hata
# çıktı | gönderme, kendim
# koptu | duramayan, giydiriyorum
# en | kenarı, bole
# allaş | boksa, digor
# basıma | rabi'mden, asmış
# sağal | kuzen, taraftar
# analı | sağlıkla, bırakmam
# sağlıkla | snsmksjs, analı
# babalı | sarma, hemcinsin
# kapalım | şoförü, i̇brahim
# şalgam | salakça, yarabbim
# kulüpte | kansızlar, vatandaş
# ...
# koptu | duramayan, giydiriyorum
# şu | ak, geçice
# ||period|| | kafeslerden, malum
# hoşuma | olmamı, açıldı
# çıktı | gönderme, kendim
# en | kenarı, bole
# sabah | vallahi, müziği
# sinir | ister, hata
# gerine | geceyi, şeyeydi
# kapalım | şoförü, i̇brahim
# babalı | sarma, hemcinsin
# büyütsün | yazılmaz, aynadan
# sağlıkla | snsmksjs, analı
# analı | sağlıkla, bırakmam
# basıma | rabi'mden, asmış
# şalgam | salakça, yarabbim
# ...
# allaş | boksa, ödevlerini
# en | kenarı, bole
# koptu | duramayan, giydiriyorum
# sabah | vallahi, müziği
# çıktı | gönderme, kendim
# hoşuma | olmamı, sevgidir
# sinir | ister, hata
# sonra | kansız, tolga
# sağal | kuzen, taraftar
# şalgam | salakça, yarabbim
# kulüpte | kansızlar, vatandaş
# babalı | sarma, hemcinsin
# analı | sağlıkla, bırakmam
# kapalım | şoförü, pembe
# sağlıkla | snsmksjs, şaapma
# büyütsün | yazılmaz, izlemeyin
# ...
# allaş | boksa, digor
# koptu | duramayan, giydiriyorum
# şu | ak, geçice
# hoşuma | olmamı, açıldı
# çıktı | gönderme, kendim
# en | kenarı, bole
# sonra | kansız, tolga
# sabah | vallahi, antrenmanı
# kapalım | şoförü, pembe
# sağal | kuzen, taraftar
# babalı | sarma, hemcinsin
# gerine | geceyi, şeyeydi
# büyütsün | yazılmaz, izlemeyin
# sağlıkla | snsmksjs, şaapma
# şalgam | salakça, yarabbim
# kulüpte | kansızlar, vatandaş
# ...
# çıktı | gönderme, kendim
# allaş | boksa, ödevlerini
# koptu | duramayan, giydiriyorum
# şu | ak, kemal
# ||period|| | kafeslerden, malum
# sinir | ister, hata
# sonra | kansız, tolga
# hoşuma | olmamı, açıldı
# analı | sağlıkla, bırakmam
# kulüpte | kansızlar, açtı
# kapalım | şoförü, i̇brahim
# büyütsün | aynadan, yazılmaz
# gerine | geceyi, şeyeydi
# sağal | kuzen, taraftar
# babalı | sarma, içmeyeceksin
# şalgam | salakça, yarabbim
# ...
# koptu | duramayan, giydiriyorum
# allaş | boksa, ödevlerini
# sabah | vallahi, antrenmanı
# ||period|| | kafeslerden, yormaz
# en | kenarı, senenin
# sonra | kansız, tolga
# şu | ak, kemal
# sinir | ister, hata
# kapalım | şoförü, i̇brahim
# sağal | taraftar, kuzen
# basıma | rabi'mden, asmış
# şalgam | salakça, çikolatanızı
# babalı | sarma, içmeyeceksin
# kulüpte | kansızlar, vatandaş
# analı | sağlıkla, bırakmam
# sağlıkla | snsmksjs, analı
# ...
# sonra | kansız, tolga
# sinir | ister, hata
# ||period|| | kafeslerden, malum
# şu | ak, kemal
# en | kenarı, senenin
# sabah | vallahi, antrenmanı
# çıktı | gönderme, kendim
# allaş | boksa, ödevlerini
# kulüpte | kansızlar, vatandaş
# babalı | sarma, içmeyeceksin
# analı | sağlıkla, bırakmam
# basıma | rabi'mden, asmış
# gerine | geceyi, şeyeydi
# kapalım | şoförü, i̇brahim
# şalgam | salakça, çikolatanızı
# sağlıkla | snsmksjs, analı
# ...
# koptu | duramayan, giydiriyorum
# ||period|| | kafeslerden, malum
# allaş | boksa, ödevlerini
# sabah | vallahi, antrenmanı
# sinir | ister, hata
# sonra | kansız, tolga
# çıktı | gönderme, kendim
# en | kenarı, senenin
# sağlıkla | snsmksjs, analı
# basıma | rabi'mden, asmış
# gerine | geceyi, şeyeydi
# kulüpte | kansızlar, vatandaş
# şalgam | salakça, çikolatanızı
# sağal | taraftar, kuzen
# büyütsün | aynadan, yazılmaz
# babalı | sarma, içmeyeceksin
# ...
# hoşuma | olmamı, sevgidir
# sonra | kansız, tolga
# koptu | giydiriyorum, duramayan
# şu | ak, sabret
# çıktı | gönderme, kendim
# sabah | vallahi, antrenmanı
# sinir | ister, hata
# en | kenarı, senenin
# analı | sağlıkla, bırakmam
# kulüpte | kansızlar, vatandaş
# babalı | sarma, içmeyeceksin
# sağlıkla | snsmksjs, analı
# şalgam | salakça, çikolatanızı
# büyütsün | aynadan, yazılmaz
# basıma | rabi'mden, asmış
# gerine | geceyi, şeyeydi
# ...
# sonra | kansız, tolga
# sinir | ister, hata
# allaş | saatten, boksa
# çıktı | gönderme, kendim
# koptu | giydiriyorum, duramayan
# ||period|| | kafeslerden, malum
# hoşuma | olmamı, sevgidir
# şu | ak, sabret
# kapalım | şoförü, i̇brahim
# şalgam | salakça, çikolatanızı
# sağlıkla | snsmksjs, analı
# büyütsün | aynadan, yazılmaz
# basıma | rabi'mden, asmış
# kulüpte | kansızlar, vatandaş
# babalı | sarma, içmeyeceksin
# sağal | taraftar, kuzen
# ...
# en | kenarı, senenin
# şu | ak, sabret
# ||period|| | kafeslerden, malum
# sonra | kansız, tolga
# sinir | ister, hata
# hoşuma | olmamı, sevgidir
# çıktı | gönderme, kendim
# allaş | saatten, boksa
# basıma | rabi'mden, asmış
# büyütsün | aynadan, yazılmaz
# analı | sağlıkla, bırakmam
# gerine | geceyi, şeyeydi
# babalı | sarma, içmeyeceksin
# kapalım | şoförü, i̇brahim
# sağlıkla | snsmksjs, analı
# kulüpte | kansızlar, vatandaş
# ...
# şu | ak, sabret
# koptu | giydiriyorum, duramayan
# çıktı | gönderme, kendim
# en | kenarı, senenin
# ||period|| | kafeslerden, malum
# allaş | saatten, boksa
# sinir | ister, hata
# hoşuma | olmamı, paniğe
# sağlıkla | snsmksjs, analı
# basıma | rabi'mden, asmış
# büyütsün | aynadan, yazılmaz
# sağal | taraftar, kuzen
# babalı | sarma, içmeyeceksin
# gerine | geceyi, şeyeydi
# şalgam | salakça, çikolatanızı
# analı | sağlıkla, bırakmam
# ...
# hoşuma | olmamı, paniğe
# şu | ak, sabret
# sabah | vallahi, antrenmanı
# koptu | duramayan, giydiriyorum
# çıktı | gönderme, kendim
# en | kenarı, senenin
# sonra | kansız, tolga
# allaş | saatten, boksa
# kapalım | şoförü, i̇brahim
# gerine | geceyi, şeyeydi
# babalı | sarma, içmeyeceksin
# basıma | rabi'mden, asmış
# sağlıkla | snsmksjs, analı
# şalgam | salakça, çikolatanızı
# kulüpte | kansızlar, vatandaş
# analı | sağlıkla, bırakmam
# ...
# sabah | vallahi, antrenmanı
# en | kenarı, senenin
# hoşuma | olmamı, paniğe
# ||period|| | kafeslerden, malum
# çıktı | gönderme, kendim
# koptu | duramayan, giydiriyorum
# şu | ak, şeyim
# sinir | ister, hata
# sağlıkla | snsmksjs, analı
# analı | sağlıkla, bırakmam
# kapalım | şoförü, i̇brahim
# büyütsün | aynadan, yazılmaz
# kulüpte | kansızlar, vatandaş
# gerine | geceyi, şeyeydi
# basıma | rabi'mden, asmış
# babalı | sarma, içmeyeceksin
# ...
# sinir | ister, hata
# koptu | duramayan, giydiriyorum
# allaş | saatten, boksa
# en | kenarı, senenin
# ||period|| | kafeslerden, malum
# şu | ak, şeyim
# sabah | vallahi, antrenmanı
# hoşuma | olmamı, paniğe
# kapalım | şoförü, i̇brahim
# sağal | taraftar, büzsüz
# basıma | rabi'mden, asmış
# büyütsün | aynadan, yazılmaz
# analı | sağlıkla, bırakmam
# kulüpte | kansızlar, vatandaş
# babalı | sarma, içmeyeceksin
# şalgam | salakça, yarabbim
# ...
# en | kenarı, senenin
# şu | ak, şeyim
# sabah | vallahi, antrenmanı
# sinir | ister, hata
# koptu | duramayan, giydiriyorum
# sonra | kansız, tolga
# hoşuma | olmamı, paniğe
# ||period|| | kafeslerden, öpen
# analı | sağlıkla, ertem
# sağal | büzsüz, taraftar
# şalgam | salakça, yarabbim
# gerine | geceyi, şeyeydi
# basıma | rabi'mden, asmış
# sağlıkla | snsmksjs, analı
# babalı | sarma, içmeyeceksin
# kapalım | şoförü, i̇brahim
# ...
# sabah | vallahi, antrenmanı
# sinir | ister, hata
# ||period|| | kafeslerden, öpen
# allaş | saatten, boksa
# hoşuma | olmamı, paniğe
# çıktı | gönderme, kendim
# şu | ak, şeyim
# en | kenarı, senenin
# basıma | rabi'mden, asmış
# kulüpte | kansızlar, vatandaş
# babalı | sarma, içmeyeceksin
# sağlıkla | snsmksjs, analı
# kapalım | şoförü, i̇brahim
# büyütsün | aynadan, yazılmaz
# sağal | büzsüz, taraftar
# gerine | geceyi, şeyeydi
# ...
# allaş | saatten, boksa
# koptu | duramayan, giydiriyorum
# çıktı | gönderme, kendim
# hoşuma | olmamı, paniğe
# sinir | ister, hata
# ||period|| | kafeslerden, öpen
# sabah | vallahi, antrenmanı
# en | kenarı, senenin
# analı | sağlıkla, ertem
# büyütsün | aynadan, yazılmaz
# gerine | geceyi, şeyeydi
# babalı | sarma, içmeyeceksin
# sağal | büzsüz, taraftar
# şalgam | salakça, yarabbim
# kapalım | şoförü, i̇brahim
# basıma | rabi'mden, asmış
# ...
# sabah | vallahi, antrenmanı
# şu | ak, sabret
# sonra | kansız, tolga
# ||period|| | kafeslerden, öpen
# en | kenarı, senenin
# çıktı | gönderme, kendim
# allaş | saatten, boksa
# koptu | duramayan, giydiriyorum
# şalgam | salakça, yarabbim
# büyütsün | aynadan, yazılmaz
# babalı | sarma, içmeyeceksin
# sağal | büzsüz, taraftar
# sağlıkla | snsmksjs, analı
# analı | sağlıkla, ertem
# kulüpte | kansızlar, vatandaş
# basıma | rabi'mden, asmış
# ...
# sonra | kansız, tolga
# allaş | saatten, boksa
# hoşuma | olmamı, paniğe
# şu | ak, sabret
# en | kenarı, senenin
# koptu | giydiriyorum, duramayan
# sinir | ister, hata
# ||period|| | kafeslerden, öpen
# sağlıkla | snsmksjs, analı
# kapalım | şoförü, i̇brahim
# sağal | büzsüz, taraftar
# babalı | sarma, içmeyeceksin
# büyütsün | aynadan, yazılmaz
# analı | sağlıkla, ertem
# kulüpte | kansızlar, vatandaş
# basıma | rabi'mden, asmış
# ...
# koptu | giydiriyorum, duramayan
# çıktı | gönderme, kendim
# ||period|| | kafeslerden, öpen
# hoşuma | olmamı, paniğe
# sonra | kansız, tolga
# en | kenarı, bole
# şu | ak, sabret
# sinir | ister, hata
# analı | sağlıkla, ertem
# şalgam | salakça, yarabbim
# gerine | geceyi, şeyeydi
# kulüpte | kansızlar, vatandaş
# babalı | sarma, içmeyeceksin
# sağlıkla | snsmksjs, analı
# sağal | büzsüz, taraftar
# kapalım | şoförü, i̇brahim
# ...
# sinir | ister, hata
# koptu | giydiriyorum, duramayan
# ||period|| | kafeslerden, malum
# sonra | kansız, tolga
# sabah | vallahi, müziği
# şu | ak, sabret
# çıktı | gönderme, kendim
# allaş | saatten, boksa
# büyütsün | aynadan, yazılmaz
# kulüpte | kansızlar, vatandaş
# basıma | rabi'mden, asmış
# kapalım | şoförü, i̇brahim
# şalgam | salakça, yarabbim
# analı | sağlıkla, ertem
# babalı | sarma, içmeyeceksin
# sağal | büzsüz, taraftar
# ...
# sinir | ister, hata
# allaş | saatten, ödevlerini
# hoşuma | olmamı, paniğe
# en | kenarı, senenin
# sabah | vallahi, müziği
# çıktı | gönderme, kendim
# sonra | kansız, tolga
# koptu | duramayan, giydiriyorum
# kapalım | şoförü, i̇brahim
# gerine | geceyi, şeyeydi
# sağal | büzsüz, taraftar
# şalgam | salakça, yarabbim
# babalı | sarma, içmeyeceksin
# analı | sağlıkla, ertem
# büyütsün | aynadan, yazılmaz
# kulüpte | kansızlar, vatandaş
# ...
# sabah | vallahi, müziği
# en | kenarı, senenin
# allaş | saatten, ödevlerini
# sinir | ister, hata
# çıktı | gönderme, kendim
# şu | ak, sabret
# sonra | kansız, tolga
# koptu | duramayan, giydiriyorum
# kulüpte | kansızlar, vatandaş
# büyütsün | aynadan, yazılmaz
# sağlıkla | snsmksjs, analı
# kapalım | şoförü, i̇brahim
# analı | sağlıkla, ertem
# şalgam | salakça, yarabbim
# babalı | sarma, içmeyeceksin
# sağal | büzsüz, taraftar
# ...
# koptu | duramayan, giydiriyorum
# şu | ak, sabret
# çıktı | gönderme, kendim
# allaş | saatten, ödevlerini
# hoşuma | olmamı, paniğe
# ||period|| | kafeslerden, öpen
# sonra | kansız, tolga
# sinir | ister, hata
# büyütsün | aynadan, yazılmaz
# babalı | sarma, içmeyeceksin
# kapalım | şoförü, i̇brahim
# gerine | geceyi, şeyeydi
# sağal | büzsüz, taraftar
# analı | sağlıkla, ertem
# kulüpte | kansızlar, vatandaş
# sağlıkla | snsmksjs, analı
# ...
# allaş | saatten, ödevlerini
# sinir | ister, hata
# ||period|| | kafeslerden, öpen
# şu | ak, sabret
# koptu | duramayan, giydiriyorum
# sonra | kansız, tolga
# sabah | vallahi, antrenmanı
# en | kenarı, senenin
# şalgam | salakça, yarabbim
# kapalım | şoförü, i̇brahim
# sağlıkla | snsmksjs, analı
# sağal | büzsüz, taraftar
# basıma | rabi'mden, asmış
# analı | sağlıkla, ertem
# gerine | geceyi, şeyeydi
# babalı | sarma, içmeyeceksin
# ...
# sabah | vallahi, antrenmanı
# en | kenarı, senenin
# çıktı | gönderme, kendim
# ||period|| | kafeslerden, öpen
# şu | ak, sabret
# sonra | kansız, tolga
# koptu | duramayan, giydiriyorum
# sinir | ister, hata
# analı | sağlıkla, ertem
# sağlıkla | snsmksjs, analı
# şalgam | salakça, yarabbim
# sağal | büzsüz, kuzen
# babalı | sarma, içmeyeceksin
# gerine | geceyi, şeyeydi
# büyütsün | aynadan, yazılmaz
# kapalım | şoförü, i̇brahim
# ...
# sabah | vallahi, antrenmanı
# sonra | kansız, komple
# hoşuma | olmamı, paniğe
# koptu | duramayan, giydiriyorum
# çıktı | gönderme, kendim
# şu | ak, sabret
# ||period|| | kafeslerden, öpen
# sinir | ister, hata
# sağal | büzsüz, kuzen
# şalgam | salakça, yarabbim
# kulüpte | kansızlar, vatandaş
# büyütsün | aynadan, yazılmaz
# gerine | geceyi, şeyeydi
# babalı | sarma, içmeyeceksin
# analı | sağlıkla, ertem
# sağlıkla | snsmksjs, analı
# ...
# sonra | kansız, komple
# ||period|| | kafeslerden, geçir
# allaş | saatten, ödevlerini
# sinir | ister, hata
# çıktı | gönderme, kendim
# en | kenarı, senenin
# şu | ak, sabret
# hoşuma | olmamı, paniğe
# sağlıkla | snsmksjs, analı
# büyütsün | aynadan, yazılmaz
# şalgam | salakça, yarabbim
# kapalım | şoförü, i̇brahim
# babalı | sarma, içmeyeceksin
# gerine | geceyi, şeyeydi
# analı | sağlıkla, ertem
# basıma | rabi'mden, asmış
# ...
# sabah | vallahi, antrenmanı
# sonra | kansız, komple
# allaş | saatten, ödevlerini
# ||period|| | kafeslerden, geçir
# en | kenarı, senenin
# sinir | ister, hata
# koptu | duramayan, giydiriyorum
# hoşuma | olmamı, paniğe
# büyütsün | aynadan, yazılmaz
# gerine | geceyi, şeyeydi
# babalı | sarma, içmeyeceksin
# sağlıkla | snsmksjs, analı
# kulüpte | kansızlar, vatandaş
# analı | sağlıkla, ertem
# sağal | büzsüz, kuzen
# şalgam | salakça, yarabbim
# ...
# koptu | duramayan, giydiriyorum
# sabah | vallahi, antrenmanı
# sonra | kansız, tolga
# sinir | ister, hata
# şu | ak, sabret
# çıktı | gönderme, kendim
# ||period|| | kafeslerden, öpen
# allaş | saatten, ödevlerini
# büyütsün | aynadan, yazılmaz
# basıma | rabi'mden, asmış
# analı | sağlıkla, ertem
# kapalım | şoförü, i̇brahim
# şalgam | salakça, yarabbim
# babalı | sarma, içmeyeceksin
# kulüpte | kansızlar, vatandaş
# sağlıkla | snsmksjs, analı
# ...
# şu | ak, sabret
# hoşuma | olmamı, paniğe
# sinir | ister, hata
# sabah | vallahi, antrenmanı
# çıktı | gönderme, kendim
# sonra | kansız, tolga
# en | kenarı, bole
# ||period|| | kafeslerden, malum
# kapalım | şoförü, i̇brahim
# sağal | büzsüz, kuzen
# basıma | rabi'mden, asmış
# kulüpte | kansızlar, vatandaş
# büyütsün | aynadan, yazılmaz
# babalı | sarma, içmeyeceksin
# şalgam | salakça, yarabbim
# gerine | geceyi, şeyeydi
# ...
# sonra | kansız, tolga
# ||period|| | kafeslerden, malum
# şu | ak, sabret
# allaş | saatten, ödevlerini
# sinir | ister, hata
# çıktı | gönderme, kendim
# hoşuma | olmamı, paniğe
# en | kenarı, bole
# sağlıkla | snsmksjs, analı
# gerine | geceyi, şeyeydi
# analı | sağlıkla, ertem
# kulüpte | kansızlar, vatandaş
# büyütsün | aynadan, izlemeyin
# sağal | büzsüz, kuzen
# şalgam | salakça, yarabbim
# basıma | rabi'mden, bağırınca
# ...
# sonra | kansız, tolga
# koptu | duramayan, giydiriyorum
# sabah | vallahi, antrenmanı
# sinir | ister, hata
# en | kenarı, senenin
# şu | ak, sabret
# çıktı | gönderme, kendim
# ||period|| | kafeslerden, öpen
# sağlıkla | snsmksjs, analı
# babalı | sarma, içmeyeceksin
# kapalım | şoförü, i̇brahim
# gerine | şeyeydi, geceyi
# kulüpte | kansızlar, vatandaş
# şalgam | salakça, yarabbim
# basıma | rabi'mden, bağırınca
# büyütsün | aynadan, izlemeyin
# ...
# sinir | ister, cık
# çıktı | gönderme, kendim
# şu | ak, sabret
# hoşuma | olmamı, paniğe
# sabah | vallahi, antrenmanı
# koptu | duramayan, giydiriyorum
# ||period|| | kafeslerden, öpen
# allaş | saatten, ödevlerini
# şalgam | salakça, yarabbim
# büyütsün | aynadan, izlemeyin
# kulüpte | kansızlar, vatandaş
# sağlıkla | snsmksjs, analı
# analı | sağlıkla, ertem
# kapalım | şoförü, i̇brahim
# basıma | rabi'mden, bağırınca
# babalı | sarma, içmeyeceksin
# ...
# sonra | kansız, tolga
# ||period|| | kafeslerden, öpen
# sinir | ister, cık
# allaş | saatten, ödevlerini
# en | kenarı, senenin
# şu | ak, sabret
# hoşuma | olmamı, paniğe
# sabah | vallahi, antrenmanı
# sağlıkla | snsmksjs, analı
# basıma | rabi'mden, bağırınca
# analı | sağlıkla, ertem
# kapalım | şoförü, i̇brahim
# şalgam | salakça, yarabbim
# kulüpte | kansızlar, vatandaş
# gerine | şeyeydi, geceyi
# babalı | sarma, içmeyeceksin
# ...
# en | kenarı, senenin
# sonra | kansız, komple
# sabah | vallahi, antrenmanı
# allaş | saatten, ödevlerini
# şu | ak, sabret
# sinir | ister, hata
# koptu | duramayan, giydiriyorum
# çıktı | gönderme, kendim
# basıma | rabi'mden, darısı
# kulüpte | kansızlar, vatandaş
# babalı | sarma, içmeyeceksin
# gerine | şeyeydi, geceyi
# şalgam | salakça, yarabbim
# sağal | kuzen, büzsüz
# kapalım | şoförü, i̇brahim
# sağlıkla | snsmksjs, analı
# ...
# çıktı | gönderme, kendim
# sabah | vallahi, antrenmanı
# şu | ak, sabret
# sonra | kansız, komple
# sinir | ister, hata
# allaş | saatten, ödevlerini
# ||period|| | kafeslerden, öpen
# koptu | duramayan, giydiriyorum
# büyütsün | aynadan, izlemeyin
# babalı | sarma, içmeyeceksin
# sağlıkla | snsmksjs, analı
# şalgam | salakça, yarabbim
# analı | sağlıkla, ertem
# sağal | kuzen, büzsüz
# basıma | rabi'mden, darısı
# kapalım | şoförü, i̇brahim
# ...
# şu | ak, sabret
# hoşuma | olmamı, paniğe
# sabah | vallahi, antrenmanı
# en | kenarı, senenin
# koptu | duramayan, giydiriyorum
# allaş | saatten, ödevlerini
# sinir | ister, hata
# ||period|| | kafeslerden, öpen
# sağlıkla | snsmksjs, analı
# kulüpte | kansızlar, vatandaş
# sağal | kuzen, büzsüz
# şalgam | salakça, yarabbim
# gerine | geceyi, şeyeydi
# kapalım | şoförü, i̇brahim
# analı | sağlıkla, ertem
# büyütsün | aynadan, izlemeyin
# ...
# en | kenarı, senenin
# sonra | kansız, komple
# sinir | ister, hata
# ||period|| | kafeslerden, öpen
# hoşuma | olmamı, paniğe
# koptu | duramayan, giydiriyorum
# şu | ak, sabret
# allaş | saatten, ödevlerini
# basıma | rabi'mden, darısı
# sağal | kuzen, büzsüz
# kapalım | şoförü, i̇brahim
# büyütsün | aynadan, izlemeyin
# babalı | sarma, cami
# şalgam | salakça, yarabbim
# sağlıkla | snsmksjs, analı
# analı | sağlıkla, ertem
# ...
# çıktı | gönderme, kendim
# ||period|| | kafeslerden, öpen
# sinir | ister, hata
# hoşuma | olmamı, paniğe
# allaş | saatten, ödevlerini
# sabah | vallahi, antrenmanı
# en | kenarı, senenin
# koptu | duramayan, giydiriyorum
# analı | sağlıkla, ertem
# büyütsün | aynadan, izlemeyin
# sağlıkla | snsmksjs, analı
# kulüpte | kansızlar, vatandaş
# basıma | rabi'mden, darısı
# babalı | sarma, cami
# kapalım | şoförü, i̇brahim
# sağal | kuzen, büzsüz
# ...
# hoşuma | olmamı, paniğe
# koptu | duramayan, giydiriyorum
# çıktı | gönderme, kendim
# sabah | vallahi, antrenmanı
# şu | ak, sabret
# sonra | kansız, komple
# en | kenarı, senenin
# allaş | saatten, ödevlerini
# gerine | geceyi, şeyeydi
# sağal | kuzen, büzsüz
# büyütsün | aynadan, izlemeyin
# kapalım | şoförü, i̇brahim
# babalı | sarma, cami
# analı | sağlıkla, ertem
# kulüpte | kansızlar, vatandaş
# sağlıkla | snsmksjs, analı
# ...
# şu | ak, sabret
# en | kenarı, senenin
# sinir | ister, cık
# sabah | vallahi, antrenmanı
# hoşuma | olmamı, paniğe
# çıktı | gönderme, baktım
# ||period|| | kafeslerden, malum
# allaş | saatten, ödevlerini
# basıma | rabi'mden, darısı
# analı | sağlıkla, ertem
# sağlıkla | snsmksjs, analı
# büyütsün | aynadan, izlemeyin
# babalı | sarma, cami
# sağal | kuzen, büzsüz
# kapalım | şoförü, i̇brahim
# kulüpte | kansızlar, vatandaş
# ...
# sonra | kansız, komple
# çıktı | gönderme, baktım
# sabah | vallahi, antrenmanı
# allaş | saatten, ödevlerini
# koptu | duramayan, seveceksin
# en | kenarı, senenin
# şu | ak, sabret
# hoşuma | olmamı, paniğe
# gerine | geceyi, şeyeydi
# büyütsün | aynadan, izlemeyin
# kulüpte | kansızlar, vatandaş
# sağlıkla | snsmksjs, analı
# babalı | sarma, cami
# şalgam | salakça, yarabbim
# analı | sağlıkla, ertem
# basıma | rabi'mden, darısı
# ...
# şu | ak, sabret
# allaş | saatten, ödevlerini
# sonra | kansız, komple
# sabah | vallahi, antrenmanı
# en | kenarı, senenin
# ||period|| | kafeslerden, öpen
# sinir | ister, cık
# çıktı | gönderme, baktım
# analı | sağlıkla, ertem
# sağal | kuzen, büzsüz
# büyütsün | aynadan, izlemeyin
# şalgam | salakça, yarabbim
# kulüpte | kansızlar, vatandaş
# gerine | geceyi, şeyeydi
# sağlıkla | snsmksjs, analı
# kapalım | şoförü, i̇brahim
# ...
# en | kenarı, senenin
# sonra | kansız, komple
# şu | ak, sabret
# allaş | saatten, ödevlerini
# ||period|| | kafeslerden, öpen
# koptu | duramayan, seveceksin
# hoşuma | olmamı, açıkçası
# sinir | ister, cık
# büyütsün | aynadan, izlemeyin
# analı | sağlıkla, ertem
# sağal | büzsüz, taraftar
# sağlıkla | snsmksjs, analı
# gerine | geceyi, ekmeğimiz
# kapalım | şoförü, i̇brahim
# kulüpte | kansızlar, vatandaş
# basıma | rabi'mden, bağırınca
# ...
# hoşuma | olmamı, açıkçası
# allaş | saatten, ödevlerini
# sinir | ister, cık
# koptu | duramayan, seveceksin
# ||period|| | kafeslerden, öpen
# çıktı | gönderme, kendim
# şu | ak, sabret
# en | senenin, kenarı
# kulüpte | kansızlar, gerisini
# kapalım | şoförü, i̇brahim
# şalgam | salakça, kanalizasyon
# sağlıkla | snsmksjs, analı
# sağal | büzsüz, taraftar
# analı | sağlıkla, ertem
# büyütsün | aynadan, adamlıktan
# babalı | sarma, cami
# ...
# en | senenin, kenarı
# sinir | ister, cık
# sabah | vallahi, antrenmanı
# allaş | ödevlerini, saatten
# koptu | duramayan, seveceksin
# çıktı | gönderme, kendim
# sonra | kansız, komple
# şu | ak, sabret
# kulüpte | kansızlar, gerisini
# kapalım | şoförü, i̇brahim
# büyütsün | aynadan, adamlıktan
# babalı | sarma, cami
# gerine | geceyi, ekmeğimiz
# basıma | rabi'mden, darısı
# sağal | büzsüz, taraftar
# sağlıkla | snsmksjs, analı
# ...
# ||period|| | kafeslerden, geçir
# sinir | ister, cık
# çıktı | gönderme, baktım
# en | senenin, kenarı
# şu | ak, sabret
# sonra | kansız, komple
# koptu | duramayan, seveceksin
# sabah | vallahi, antrenmanı
# kulüpte | kansızlar, gerisini
# şalgam | salakça, kanalizasyon
# gerine | geceyi, ekmeğimiz
# babalı | sarma, cami
# sağal | büzsüz, taraftar
# sağlıkla | snsmksjs, analı
# büyütsün | aynadan, adamlıktan
# basıma | rabi'mden, darısı
# ...
# sinir | ister, hata
# şu | ak, sabret
# allaş | saatten, ödevlerini
# çıktı | gönderme, baktım
# sabah | vallahi, antrenmanı
# sonra | kansız, komple
# en | senenin, kenarı
# hoşuma | olmamı, paniğe
# basıma | rabi'mden, darısı
# gerine | geceyi, şeyeydi
# sağlıkla | snsmksjs, analı
# şalgam | salakça, kanalizasyon
# analı | sağlıkla, ertem
# büyütsün | aynadan, adamlıktan
# sağal | büzsüz, taraftar
# babalı | sarma, cami
# ...
# en | senenin, kenarı
# şu | ak, sabret
# sabah | vallahi, antrenmanı
# ||period|| | kafeslerden, öpen
# çıktı | gönderme, baktım
# allaş | saatten, ödevlerini
# sonra | komple, kansız
# sinir | ister, hata
# sağal | büzsüz, taraftar
# gerine | geceyi, şeyeydi
# kulüpte | kansızlar, gerisini
# analı | sağlıkla, ertem
# babalı | sarma, cami
# basıma | rabi'mden, darısı
# büyütsün | aynadan, adamlıktan
# sağlıkla | snsmksjs, analı
# ...
# ||period|| | kafeslerden, öpen
# en | senenin, kenarı
# allaş | saatten, boksa
# sonra | komple, kansız
# hoşuma | olmamı, paniğe
# sinir | ister, cık
# sabah | vallahi, antrenmanı
# şu | ak, sabret
# kapalım | şoförü, i̇brahim
# gerine | geceyi, şeyeydi
# büyütsün | aynadan, adamlıktan
# basıma | rabi'mden, darısı
# kulüpte | kansızlar, gerisini
# şalgam | salakça, kanalizasyon
# babalı | sarma, cami
# sağal | büzsüz, taraftar
# ...
# sabah | vallahi, antrenmanı
# çıktı | gönderme, baktım
# sonra | komple, kansız
# en | senenin, kenarı
# allaş | saatten, boksa
# koptu | duramayan, giydiriyorum
# sinir | ister, cık
# ||period|| | kafeslerden, malum
# kapalım | şoförü, i̇brahim
# kulüpte | kansızlar, gerisini
# sağlıkla | snsmksjs, analı
# basıma | rabi'mden, darısı
# büyütsün | aynadan, adamlıktan
# şalgam | salakça, kanalizasyon
# analı | sağlıkla, ertem
# sağal | büzsüz, taraftar
# ...
# çıktı | gönderme, baktım
# hoşuma | olmamı, paniğe
# şu | ak, sabret
# koptu | duramayan, giydiriyorum
# en | senenin, kenarı
# sinir | ister, cık
# sonra | komple, kansız
# ||period|| | kafeslerden, malum
# gerine | geceyi, şeyeydi
# sağlıkla | snsmksjs, analı
# analı | sağlıkla, ertem
# büyütsün | aynadan, izlemeyin
# sağal | büzsüz, taraftar
# babalı | sarma, cami
# kulüpte | kansızlar, gerisini
# şalgam | salakça, kanalizasyon
# ...
# sonra | komple, kansız
# allaş | saatten, ödevlerini
# sinir | ister, cık
# en | senenin, kenarı
# hoşuma | olmamı, paniğe
# çıktı | gönderme, baktım
# sabah | vallahi, antrenmanı
# şu | ak, sabret
# sağlıkla | snsmksjs, analı
# kulüpte | kansızlar, gerisini
# sağal | büzsüz, taraftar
# basıma | rabi'mden, darısı
# babalı | sarma, cami
# kapalım | şoförü, i̇brahim
# şalgam | salakça, kanalizasyon
# gerine | geceyi, şeyeydi
# ...
# en | senenin, kenarı
# hoşuma | olmamı, paniğe
# koptu | duramayan, seveceksin
# sinir | ister, cık
# çıktı | gönderme, baktım
# ||period|| | kafeslerden, öpen
# sabah | vallahi, antrenmanı
# şu | ak, sabret
# basıma | rabi'mden, darısı
# sağal | büzsüz, taraftar
# kulüpte | kansızlar, gerisini
# babalı | sarma, cami
# analı | sağlıkla, ertem
# gerine | geceyi, şeyeydi
# büyütsün | aynadan, izlemeyin
# sağlıkla | snsmksjs, analı
# ...
# koptu | duramayan, seveceksin
# allaş | saatten, ödevlerini
# en | senenin, kenarı
# hoşuma | olmamı, açıkçası
# sinir | ister, cık
# şu | ak, sabret
# sabah | vallahi, antrenmanı
# sonra | komple, kansız
# kulüpte | kansızlar, gerisini
# sağlıkla | snsmksjs, analı
# babalı | sarma, evi
# analı | sağlıkla, büyütün
# büyütsün | aynadan, izlemeyin
# sağal | taraftar, büzsüz
# şalgam | salakça, yarabbim
# gerine | geceyi, ekmeğimiz
# ...
# şu | ak, sabret
# en | senenin, kenarı
# allaş | saatten, ödevlerini
# hoşuma | olmamı, açıkçası
# çıktı | gönderme, baktım
# ||period|| | kafeslerden, öpen
# sinir | ister, cık
# koptu | duramayan, seveceksin
# gerine | geceyi, ekmeğimiz
# kulüpte | kansızlar, gerisini
# büyütsün | aynadan, izlemeyin
# kapalım | şoförü, i̇brahim
# basıma | rabi'mden, bağırınca
# şalgam | salakça, yarabbim
# sağlıkla | snsmksjs, analı
# analı | sağlıkla, büyütün
# ...
# hoşuma | olmamı, paniğe
# en | senenin, kenarı
# çıktı | gönderme, baktım
# sinir | ister, cık
# ||period|| | kafeslerden, öpen
# şu | ak, geçice
# koptu | duramayan, seveceksin
# sabah | vallahi, antrenmanı
# basıma | rabi'mden, bağırınca
# kulüpte | kansızlar, gerisini
# kapalım | şoförü, i̇brahim
# sağal | büzsüz, taraftar
# babalı | sarma, cami
# sağlıkla | snsmksjs, analı
# analı | sağlıkla, büyütün
# şalgam | salakça, yarabbim
# ...
# sabah | vallahi, antrenmanı
# allaş | saatten, ödevlerini
# ||period|| | kafeslerden, öpen
# çıktı | gönderme, baktım
# şu | ak, sabret
# sinir | ister, cık
# sonra | komple, kansız
# hoşuma | olmamı, paniğe
# sağlıkla | snsmksjs, analı
# basıma | rabi'mden, bağırınca
# kulüpte | kansızlar, gerisini
# şalgam | salakça, yarabbim
# babalı | sarma, cami
# kapalım | şoförü, i̇brahim
# gerine | şeyeydi, geceyi
# analı | sağlıkla, büyütün
# ...
# sinir | ister, cık
# allaş | saatten, ödevlerini
# sabah | vallahi, antrenmanı
# şu | ak, geçice
# sonra | komple, kansız
# koptu | duramayan, seveceksin
# çıktı | gönderme, baktım
# hoşuma | olmamı, paniğe
# gerine | şeyeydi, geceyi
# büyütsün | aynadan, izlemeyin
# kapalım | şoförü, i̇brahim
# kulüpte | kansızlar, gerisini
# babalı | sarma, cami
# şalgam | yarabbim, salakça
# sağal | büzsüz, taraftar
# analı | sağlıkla, büyütün
# ...
# koptu | duramayan, seveceksin
# en | senenin, kenarı
# allaş | saatten, boksa
# şu | ak, geçice
# sinir | ister, cık
# sonra | komple, kansız
# ...
# ...
# hoşuma | atmazsam, açıkçası
# allaş | çocuğumuz, analı
# şu | onunla, tüvitte
# sinir | ister, cık
# ||period|| | kazanıyorsun, öpen
# koptu | yavuz, sürmektir
# sonra | olmamı, yakalandım
# çıktı | plaka, kürklü
# gerine | yatağımda, yuvarlanıyorum
# kapalım | kaldın, yapmışsın
# büyütsün | analı, babalı
# şalgam | dkskdkfk, dili
# sağal | aralıksız, çekiliş
# babalı | büyütsün, analı
# sağlıkla | tatlısınız, yaşayın
# analı | büyütsün, babalı
# ...
# ||period|| | kazanıyorsun, öpen
# koptu | yavuz, sürmektir
# sinir | ister, cık
# şu | onunla, tüvitte
# çıktı | plaka, kürklü
# sabah | demeye, sarıya
# allaş | çocuğumuz, analı
# en | senenin, hmmm
# gerine | yatağımda, yuvarlanıyorum
# analı | büyütsün, babalı
# sağal | aralıksız, çekiliş
# sağlıkla | tatlısınız, yaşayın
# kulüpte | akalından, duymuyorum
# basıma | aydınlık, hayvana
# kapalım | kaldın, yapmışsın
# şalgam | dkskdkfk, dili
# ...
# şu | onunla, tüvitte
# hoşuma | atmazsam, açıkçası
# koptu | yavuz, sürmektir
# ||period|| | kazanıyorsun, öpen
# sonra | olmamı, yakalandım
# allaş | çocuğumuz, analı
# en | senenin, hmmm
# çıktı | plaka, kürklü
# büyütsün | analı, babalı
# şalgam | dkskdkfk, dili
# sağal | aralıksız, çekiliş
# gerine | yatağımda, yuvarlanıyorum
# sağlıkla | tatlısınız, yaşayın
# babalı | büyütsün, analı
# kapalım | kaldın, yapmışsın
# basıma | aydınlık, hayvana
# ...
# sinir | ister, cık
# ||period|| | kazanıyorsun, öpen
# sonra | olmamı, yakalandım
# sabah | demeye, sarıya
# hoşuma | atmazsam, açıkçası
# çıktı | plaka, kürklü
# en | senenin, hmmm
# şu | onunla, tüvitte
# kulüpte | akalından, duymuyorum
# gerine | yatağımda, yuvarlanıyorum
# babalı | büyütsün, analı
# basıma | aydınlık, hayvana
# büyütsün | analı, babalı
# analı | büyütsün, babalı
# kapalım | kaldın, yapmışsın
# şalgam | dkskdkfk, dili
# ...
# sinir | ister, cık
# en | senenin, hmmm
# sabah | demeye, sarıya
# hoşuma | atmazsam, açıkçası
# allaş | çocuğumuz, analı
# ||period|| | kazanıyorsun, öpen
# şu | onunla, tüvitte
# çıktı | plaka, kürklü
# büyütsün | analı, babalı
# analı | büyütsün, babalı
# gerine | yatağımda, yuvarlanıyorum
# kulüpte | akalından, duymuyorum
# basıma | aydınlık, hayvana
# kapalım | kaldın, yapmışsın
# şalgam | dkskdkfk, dili
# sağal | aralıksız, çekiliş
# ...
# şu | onunla, tüvitte
# sinir | ister, cık
# sonra | olmamı, yakalandım
# çıktı | plaka, kürklü
# sabah | demeye, sarıya
# koptu | yavuz, sürmektir
# allaş | çocuğumuz, analı
# ||period|| | kazanıyorsun, öpen
# analı | büyütsün, babalı
# sağlıkla | tatlısınız, yaşayın
# babalı | büyütsün, analı
# kulüpte | duymuyorum, akalından
# kapalım | kaldın, yapmışsın
# şalgam | dkskdkfk, dili
# büyütsün | analı, babalı
# basıma | aydınlık, hayvana
# ...
# çıktı | plaka, kürklü
# en | senenin, hmmm
# sonra | olmamı, yakalandım
# koptu | yavuz, sürmektir
# sabah | demeye, sarıya
# allaş | çocuğumuz, analı
# sinir | ister, cık
# hoşuma | atmazsam, açıkçası
# analı | büyütsün, babalı
# şalgam | dkskdkfk, dili
# basıma | aydınlık, eylesin
# babalı | büyütsün, analı
# büyütsün | analı, babalı
# gerine | yatağımda, halinize
# sağal | aralıksız, çekiliş
# kulüpte | akalından, duymuyorum
# ...
# allaş | çocuğumuz, analı
# sonra | olmamı, yakalandım
# ||period|| | kazanıyorsun, öpen
# şu | onunla, tüvitte
# koptu | yavuz, sürmektir
# en | senenin, hmmm
# hoşuma | atmazsam, açıkçası
# çıktı | plaka, kürklü
# analı | büyütsün, babalı
# basıma | aydınlık, eylesin
# kapalım | kaldın, yapmışsın
# sağal | aralıksız, çekiliş
# sağlıkla | tatlısınız, yaşayın
# babalı | büyütsün, analı
# kulüpte | akalından, duymuyorum
# şalgam | dkskdkfk, dili
# ...
# allaş | çocuğumuz, analı
# şu | onunla, tüvitte
# sonra | olmamı, yakalandım
# koptu | yavuz, sürmektir
# sinir | ister, cık
# ||period|| | kazanıyorsun, öpen
# sabah | demeye, sarıya
# en | senenin, hmmm
# basıma | aydınlık, eylesin
# kulüpte | akalından, duymuyorum
# kapalım | kaldın, yapmışsın
# şalgam | dkskdkfk, dili
# büyütsün | analı, babalı
# analı | büyütsün, babalı
# sağal | aralıksız, çekiliş
# babalı | büyütsün, analı
# ...
# hoşuma | atmazsam, açıkçası
# sinir | ister, cık
# ||period|| | kazanıyorsun, öpen
# sabah | demeye, sarıya
# allaş | çocuğumuz, analı
# çıktı | plaka, kürklü
# en | senenin, hmmm
# şu | onunla, tüvitte
# büyütsün | analı, babalı
# analı | büyütsün, babalı
# babalı | büyütsün, analı
# şalgam | dkskdkfk, dili
# sağal | aralıksız, çekiliş
# sağlıkla | tatlısınız, yaşayın
# kulüpte | akalından, duymuyorum
# gerine | yatağımda, halinize
# ...
# çıktı | plaka, kürklü
# sinir | ister, cık
# sonra | olmamı, yakalandım
# hoşuma | atmazsam, açıkçası
# allaş | çocuğumuz, analı
# en | senenin, hmmm
# sabah | demeye, sarıya
# şu | onunla, tüvitte
# basıma | aydınlık, eylesin
# kulüpte | akalından, duymuyorum
# analı | büyütsün, babalı
# büyütsün | analı, babalı
# babalı | büyütsün, analı
# gerine | yatağımda, halinize
# sağal | aralıksız, çekiliş
# kapalım | kaldın, yapmışsın
# ...
# çıktı | plaka, kürklü
# hoşuma | atmazsam, açıkçası
# ||period|| | kazanıyorsun, öpen
# şu | onunla, tüvitte
# sabah | demeye, sarıya
# allaş | çocuğumuz, analı
# sinir | ister, cık
# sonra | olmamı, yakalandım
# gerine | yatağımda, halinize
# sağlıkla | tatlısınız, yaşayın
# kapalım | kaldın, yapmışsın
# kulüpte | akalından, duymuyorum
# babalı | büyütsün, analı
# basıma | aydınlık, eylesin
# analı | büyütsün, babalı
# şalgam | dkskdkfk, dili
# ...
# sonra | olmamı, yakalandım
# ||period|| | kazanıyorsun, öpen
# en | senenin, hmmm
# sabah | demeye, sarıya
# şu | onunla, tüvitte
# çıktı | plaka, kürklü
# sinir | ister, cık
# allaş | çocuğumuz, analı
# sağal | aralıksız, çekiliş
# gerine | yatağımda, halinize
# şalgam | dkskdkfk, dili
# analı | büyütsün, babalı
# sağlıkla | tatlısınız, yaşayın
# babalı | büyütsün, analı
# kapalım | kaldın, yapmışsın
# kulüpte | akalından, duymuyorum
# ...
# ||period|| | kazanıyorsun, öpen
# şu | onunla, tüvitte
# sabah | demeye, sarıya
# allaş | çocuğumuz, analı
# çıktı | plaka, kürklü
# sinir | ister, cık
# sonra | olmamı, yakalandım
# hoşuma | atmazsam, açıkçası
# kulüpte | akalından, duymuyorum
# gerine | yatağımda, halinize
# sağal | aralıksız, çekiliş
# şalgam | dkskdkfk, dili
# kapalım | kaldın, yapmışsın
# büyütsün | analı, babalı
# sağlıkla | tatlısınız, yaşayın
# basıma | aydınlık, eylesin
# ...
# allaş | çocuğumuz, analı
# sonra | olmamı, yakalandım
# hoşuma | atmazsam, açıkçası
# en | senenin, hmmm
# şu | onunla, tüvitte
# çıktı | plaka, kürklü
# ||period|| | kazanıyorsun, öpen
# sabah | demeye, kapatıyor
# analı | büyütsün, babalı
# sağlıkla | tatlısınız, yaşayın
# kapalım | kaldın, yapmışsın
# basıma | aydınlık, eylesin
# sağal | aralıksız, çekiliş
# kulüpte | akalından, duymuyorum
# gerine | yatağımda, halinize
# büyütsün | analı, babalı
# ...
# sinir | ister, cık
# ||period|| | öpen, kazanıyorsun
# koptu | yavuz, sürmektir
# hoşuma | atmazsam, açıkçası
# çıktı | plaka, kürklü
# sabah | demeye, kapatıyor
# en | senenin, hmmm
# sonra | olmamı, yakalandım
# analı | büyütsün, babalı
# gerine | yatağımda, yuvarlanıyorum
# babalı | büyütsün, analı
# kulüpte | duymuyorum, akalından
# sağal | aralıksız, sınavlarının
# büyütsün | babalı, analı
# şalgam | dili, dkskdkfk
# basıma | aydınlık, eylesin
# ...
# en | senenin, hmmm
# koptu | yavuz, sürmektir
# sonra | olmamı, yakalandım
# sabah | demeye, kapatıyor
# hoşuma | atmazsam, açıkçası
# çıktı | plaka, kürklü
# allaş | çocuğumuz, analı
# sinir | ister, cık
# büyütsün | babalı, analı
# babalı | büyütsün, analı
# sağal | aralıksız, sınavlarının
# kulüpte | akalından, arabanda
# analı | büyütsün, babalı
# gerine | yatağımda, yuvarlanıyorum
# şalgam | dili, dkskdkfk
# basıma | aydınlık, eylesin
# ...
# allaş | çocuğumuz, analı
# sabah | demeye, sarıya
# koptu | yavuz, sürmektir
# sonra | olmamı, yakalandım
# sinir | ister, cık
# en | senenin, hmmm
# hoşuma | atmazsam, açıkçası
# şu | onunla, tüvitte
# analı | büyütsün, babalı
# büyütsün | babalı, analı
# sağal | aralıksız, sınavlarının
# babalı | büyütsün, analı
# sağlıkla | tatlısınız, yaşayın
# kapalım | kaldın, yapmışsın
# basıma | aydınlık, eylesin
# şalgam | dili, dkskdkfk
# ...
# sinir | ister, cık
# şu | onunla, tüvitte
# çıktı | plaka, kürklü
# allaş | çocuğumuz, analı
# ||period|| | kazanıyorsun, öpen
# sonra | olmamı, yakalandım
# hoşuma | atmazsam, açıkçası
# sabah | demeye, kapatıyor
# basıma | aydınlık, eylesin
# babalı | büyütsün, analı
# sağlıkla | tatlısınız, yaşayın
# kulüpte | akalından, arabanda
# analı | büyütsün, babalı
# şalgam | dili, dkskdkfk
# gerine | yatağımda, yuvarlanıyorum
# sağal | aralıksız, sınavlarının
# ...
# ||period|| | kazanıyorsun, öpen
# sabah | demeye, kapatıyor
# şu | onunla, tüvitte
# sonra | olmamı, yakalandım
# en | senenin, hmmm
# çıktı | plaka, kürklü
# hoşuma | atmazsam, açıkçası
# sinir | ister, kalma
# büyütsün | babalı, analı
# basıma | aydınlık, eylesin
# sağlıkla | tatlısınız, yaşayın
# kapalım | kaldın, yapmışsın
# kulüpte | akalından, arabanda
# analı | büyütsün, babalı
# gerine | yatağımda, yuvarlanıyorum
# sağal | aralıksız, sınavlarının
# ...
# koptu | yavuz, sürmektir
# ||period|| | kazanıyorsun, öpen
# sinir | ister, cık
# sonra | olmamı, yakalandım
# hoşuma | atmazsam, açıkçası
# allaş | çocuğumuz, analı
# en | senenin, bilmiyosanız
# çıktı | plaka, kürklü
# babalı | büyütsün, analı
# şalgam | dili, dkskdkfk
# kapalım | kaldın, yapmışsın
# gerine | yatağımda, yuvarlanıyorum
# sağal | aralıksız, sınavlarının
# basıma | aydınlık, eylesin
# kulüpte | akalından, arabanda
# büyütsün | babalı, analı
# ...
# çıktı | plaka, kürklü
# sonra | olmamı, yakalandım
# şu | onunla, tüvitte
# sabah | demeye, kapatıyor
# hoşuma | atmazsam, açıkçası
# koptu | yavuz, sürmektir
# en | senenin, hmmm
# sinir | ister, cık
# sağlıkla | tatlısınız, yaşayın
# basıma | aydınlık, eylesin
# gerine | yatağımda, yuvarlanıyorum
# kulüpte | akalından, arabanda
# analı | büyütsün, babalı
# sağal | aralıksız, sınavlarının
# şalgam | dili, dkskdkfk
# babalı | büyütsün, analı
# ...
# şu | onunla, tüvitte
# ||period|| | kazanıyorsun, öpen
# sinir | ister, cık
# koptu | yavuz, sürmektir
# sabah | demeye, kapatıyor
# sonra | olmamı, yakalandım
# hoşuma | atmazsam, açıkçası
# allaş | çocuğumuz, analı
# babalı | büyütsün, analı
# büyütsün | babalı, analı
# sağlıkla | tatlısınız, yaşayın
# sağal | aralıksız, sınavlarının
# gerine | yatağımda, yuvarlanıyorum
# kapalım | kaldın, yapmışsın
# şalgam | dili, dkskdkfk
# basıma | aydınlık, eylesin
# ...
# çıktı | plaka, kürklü
# ||period|| | kazanıyorsun, öpen
# allaş | çocuğumuz, analı
# koptu | yavuz, sürmektir
# sonra | olmamı, yakalandım
# sabah | demeye, sarıya
# en | senenin, hmmm
# şu | onunla, tüvitte
# kulüpte | akalından, arabanda
# gerine | yatağımda, yuvarlanıyorum
# sağal | aralıksız, sınavlarının
# babalı | büyütsün, analı
# şalgam | dili, dkskdkfk
# kapalım | kaldın, yapmışsın
# büyütsün | babalı, analı
# basıma | aydınlık, eylesin
# ...
# sabah | demeye, kapatıyor
# ||period|| | kazanıyorsun, öpen
# hoşuma | atmazsam, açıkçası
# şu | onunla, tüvitte
# çıktı | plaka, kürklü
# sonra | olmamı, yakalandım
# sinir | ister, cık
# allaş | çocuğumuz, gençliğimi
# basıma | aydınlık, eylesin
# kulüpte | akalından, arabanda
# sağal | aralıksız, sınavlarının
# şalgam | dili, dkskdkfk
# büyütsün | babalı, analı
# babalı | büyütsün, analı
# gerine | yatağımda, yuvarlanıyorum
# sağlıkla | tatlısınız, yaşayın
# ...
# ||period|| | yardıma, öpen
# allaş | çocuğumuz, analı
# sonra | olmamı, yakalandım
# şu | onunla, tüvitte
# çıktı | plaka, kürklü
# en | senenin, hmmm
# hoşuma | atmazsam, açıkçası
# koptu | yavuz, sürmektir
# kapalım | kaldın, yapmışsın
# analı | büyütsün, babalı
# sağlıkla | tatlısınız, yaşayın
# babalı | büyütsün, analı
# şalgam | dili, dkskdkfk
# kulüpte | akalından, arabanda
# basıma | aydınlık, eylesin
# gerine | yatağımda, halinize
# ...
# sinir | ister, cık
# en | senenin, hmmm
# sonra | olmamı, yakalandım
# şu | onunla, tüvitte
# koptu | yavuz, sürmektir
# hoşuma | atmazsam, açıkçası
# allaş | çocuğumuz, analı
# ||period|| | yardıma, kazanıyorsun
# sağal | aralıksız, dersiniz
# şalgam | dkskdkfk, dili
# sağlıkla | tatlısınız, yaşayın
# gerine | yatağımda, halinize
# büyütsün | analı, babalı
# analı | büyütsün, babalı
# kulüpte | akalından, duymuyorum
# babalı | büyütsün, analı
# ...
# hoşuma | atmazsam, açıkçası
# koptu | yavuz, sürmektir
# en | senenin, hmmm
# şu | onunla, tüvitte
# çıktı | plaka, kürklü
# sinir | ister, cık
# sonra | olmamı, yakalandım
# allaş | çocuğumuz, analı
# şalgam | dkskdkfk, dili
# sağlıkla | tatlısınız, yaşayın
# gerine | yatağımda, halinize
# analı | büyütsün, babalı
# kulüpte | akalından, duymuyorum
# basıma | aydınlık, hayvana
# büyütsün | analı, babalı
# sağal | aralıksız, dersiniz
# ...
# allaş | çocuğumuz, analı
# sabah | demeye, kapatıyor
# ||period|| | kazanıyorsun, öpen
# şu | onunla, tüvitte
# koptu | yavuz, sürmektir
# sinir | ister, cık
# en | senenin, hmmm
# çıktı | plaka, kürklü
# sağal | aralıksız, dersiniz
# kulüpte | akalından, duymuyorum
# kapalım | kaldın, yapmışsın
# büyütsün | analı, babalı
# analı | büyütsün, babalı
# şalgam | dkskdkfk, dili
# sağlıkla | tatlısınız, yaşayın
# gerine | yatağımda, halinize
# ...
# hoşuma | atmazsam, açıkçası
# sonra | olmamı, yakalandım
# koptu | yavuz, sürmektir
# sinir | ister, cık
# sabah | demeye, kapatıyor
# şu | onunla, tüvitte
# çıktı | plaka, kürklü
# en | senenin, bilmiyosanız
# sağlıkla | tatlısınız, yaşayın
# büyütsün | analı, babalı
# analı | büyütsün, babalı
# şalgam | dkskdkfk, dili
# sağal | aralıksız, dersiniz
# gerine | yatağımda, halinize
# babalı | büyütsün, analı
# kapalım | kaldın, yapmışsın
# ...
# sabah | demeye, kapatıyor
# ||period|| | kazanıyorsun, yardıma
# en | senenin, hmmm
# şu | onunla, tüvitte
# hoşuma | atmazsam, açıkçası
# allaş | çocuğumuz, analı
# koptu | yavuz, sürmektir
# sinir | ister, defolun
# babalı | büyütsün, analı
# kapalım | kaldın, yapmışsın
# sağlıkla | tatlısınız, yaşayın
# kulüpte | akalından, duymuyorum
# gerine | yatağımda, halinize
# basıma | aydınlık, hayvana
# büyütsün | analı, babalı
# şalgam | dkskdkfk, dili
# ...
# hoşuma | atmazsam, açıkçası
# ||period|| | kazanıyorsun, öpen
# en | senenin, hmmm
# sonra | olmamı, yakalandım
# koptu | yavuz, sürmektir
# sabah | demeye, kapatıyor
# şu | onunla, tüvitte
# allaş | çocuğumuz, analı
# analı | büyütsün, babalı
# sağal | aralıksız, dersiniz
# kulüpte | akalından, duymuyorum
# kapalım | kaldın, yapmışsın
# gerine | yatağımda, halinize
# şalgam | dkskdkfk, dili
# babalı | büyütsün, analı
# sağlıkla | tatlısınız, yaşayın
# ...
# hoşuma | atmazsam, açıkçası
# koptu | yavuz, sürmektir
# sonra | olmamı, yakalandım
# şu | onunla, tüvitte
# sabah | demeye, kapatıyor
# en | senenin, hmmm
# allaş | çocuğumuz, analı
# ||period|| | yardıma, kazanıyorsun
# basıma | aydınlık, hayvana
# sağal | aralıksız, dersiniz
# şalgam | dkskdkfk, dili
# kulüpte | akalından, duymuyorum
# gerine | yatağımda, halinize
# babalı | büyütsün, analı
# kapalım | kaldın, yapmışsın
# analı | büyütsün, babalı
# ...
# şu | onunla, tüvitte
# sinir | ister, defolun
# ||period|| | kazanıyorsun, yardıma
# hoşuma | atmazsam, açıkçası
# allaş | çocuğumuz, analı
# sabah | demeye, sarıya
# sonra | olmamı, yakalandım
# çıktı | plaka, kürklü
# basıma | aydınlık, hayvana
# kulüpte | akalından, duymuyorum
# büyütsün | analı, babalı
# babalı | büyütsün, analı
# kapalım | kaldın, yapmışsın
# sağlıkla | tatlısınız, yaşayın
# gerine | yatağımda, halinize
# sağal | aralıksız, dersiniz
# ...
# ||period|| | yardıma, öpen
# sonra | olmamı, yakalandım
# hoşuma | atmazsam, açıkçası
# sinir | ister, defolun
# çıktı | plaka, kürklü
# en | senenin, hmmm
# allaş | çocuğumuz, analı
# şu | onunla, tüvitte
# sağal | aralıksız, dersiniz
# sağlıkla | tatlısınız, yaşayın
# kapalım | kaldın, yapmışsın
# babalı | büyütsün, analı
# şalgam | dkskdkfk, dili
# basıma | aydınlık, hayvana
# gerine | yatağımda, halinize
# kulüpte | akalından, duymuyorum
# ...
# sinir | ister, defolun
# sonra | olmamı, yakalandım
# şu | onunla, tüvitte
# koptu | yavuz, sürmektir
# hoşuma | atmazsam, açıkçası
# allaş | çocuğumuz, analı
# en | senenin, hmmm
# ||period|| | öpen, yardıma
# kapalım | kaldın, yapmışsın
# sağal | aralıksız, dersiniz
# şalgam | dkskdkfk, dili
# büyütsün | analı, babalı
# kulüpte | akalından, duymuyorum
# sağlıkla | tatlısınız, yaşayın
# basıma | aydınlık, hayvana
# babalı | büyütsün, analı
# ...
# hoşuma | atmazsam, açıkçası
# şu | onunla, tüvitte
# en | senenin, hmmm
# çıktı | plaka, kürklü
# sonra | olmamı, yakalandım
# sinir | ister, defolun
# allaş | çocuğumuz, analı
# koptu | yavuz, sürmektir
# kapalım | kaldın, yapmışsın
# analı | büyütsün, babalı
# sağal | aralıksız, bitirdik
# sağlıkla | tatlısınız, yaşayın
# büyütsün | babalı, analı
# şalgam | dili, dkskdkfk
# kulüpte | akalından, arabanda
# basıma | aydınlık, hayvana
# ...
# en | senenin, hmmm
# allaş | çocuğumuz, analı
# ||period|| | kazanıyorsun, öpen
# koptu | yavuz, sürmektir
# şu | onunla, tüvitte
# sonra | olmamı, yakalandım
# sinir | ister, defolun
# hoşuma | atmazsam, açıkçası
# analı | büyütsün, babalı
# büyütsün | babalı, analı
# gerine | yatağımda, halinize
# şalgam | dili, dkskdkfk
# kapalım | kaldın, yapmışsın
# basıma | aydınlık, hayvana
# kulüpte | akalından, arabanda
# sağlıkla | tatlısınız, yaşayın
# ...
